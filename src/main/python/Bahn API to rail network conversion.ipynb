# %% [markdown]
# # Bahn API to rail network conversion

# %% [markdown]
# General setup and initialization:

# %%
from datetime import datetime
import json

import requests

date_format = "%Y-%m-%d"
today = datetime.now().strftime(date_format)
today_short = datetime.now().strftime("%y%m%d")


# stations with stops for long distance connections
ld_location_base_url = "https://api.deutschebahn.com/fahrplan-plus/v1/location/"

# arrival board for long distance connections
ld_arrival_base_url = "https://api.deutschebahn.com/fahrplan-plus/v1/arrivalBoard/"

# all stations, no matter what connections are offered
station_overview_url = "https://api.deutschebahn.com/stada/v2/stations/"

timetable_base_url = "https://api.deutschebahn.com/timetables/v1/plan/"


auth_token = ""
with open("auth.json", "r") as auth_file:
    auth_data = json.load(auth_file)
    auth_token = auth_data["token"]
base_headers = {"Authorization": auth_token, "Accept": "application/json"}
# Out:
# Bearer f26a780b3a3767f808d7f1c39c4be75d

# %% [markdown]
# ## Long-distance connection checks

# %% [markdown]
# Get all stations in Dresden, which provide access to long distance connections

# %%
r = requests.get(ld_location_base_url + "dresden", headers=base_headers)
r
# Out:
# <Response [200]>

# %%
matches = r.json()
matches
# Out:
# [{'name': 'Dresden Hbf', 'lon': 13.732039, 'lat': 51.040562, 'id': 8010085},
#  {'name': 'Dresden-Neustadt',
#   'lon': 13.740704,
#   'lat': 51.065903,
#   'id': 8010089}]

# %% [markdown]
# We will look at Dresden main station in more detail now.

# %%
dd_hbf = next(station for station in matches if "Hbf" in station["name"])
dd_hbf
# Out:
# {'name': 'Dresden Hbf', 'lon': 13.732039, 'lat': 51.040562, 'id': 8010085}

# %% [markdown]
# Query for all long distance connections for today:

# %%
r = requests.get(ld_arrival_base_url + str(dd_hbf["id"]), headers=base_headers, params={"date": today})
r
# Out:
# <Response [200]>

# %%
r.json()
# Out:
# [{'name': 'IC 2249',
#   'type': 'IC',
#   'boardId': 8010085,
#   'stopId': 8010085,
#   'stopName': 'Dresden Hbf',
#   'dateTime': '2021-10-27T07:37',
#   'origin': 'Leipzig Hbf',
#   'track': '1',
#   'detailsId': '29493%2F17213%2F162576%2F71457%2F80%3fstation_evaId%3D8010085'},
#  {'name': 'RJ 257',
#   'type': 'RJ',
#   'boardId': 8010085,
#   'stopId': 8010085,
#   'stopName': 'Dresden Hbf',
#   'dateTime': '2021-10-27T08:07',
#   'origin': 'Berlin Hbf &#x0028;tief&#x0029;',
#   'track': '1',
#   'detailsId': '249381%2F103607%2F271114%2F52430%2F80%3fstation_evaId%3D8010085'},
#  {'name': 'IC 2449',
#   'type': 'IC',
#   'boardId': 8010085,
#   'stopId': 8010085,
#   'stopName': 'Dresden Hbf',
#   'dateTime': '2021-10-27T08:44',
#   'origin': 'Magdeburg Hbf',
#   'track': '3',
#   'detailsId': '525297%2F183907%2F742436%2F196119%2F80%3fstation_evaId%3D8010085'},
#  {'name': 'EC 178',
#   'type': 'EC',
#   'boardId': 8010085,
#   'stopId': 8010085,
#   'stopName': 'Dresden Hbf',
#   'dateTime': '2021-10-27T08:52',
#   'origin': 'Praha hl.n.',
#   'track': '12',
#   'detailsId': '236877%2F98847%2F641840%2F241961%2F80%3fstation_evaId%3D8010085'},
#  {'name': 'EC 171',
#   'type': 'EC',
#   'boardId': 8010085,
#   'stopId': 8010085,
#   'stopName': 'Dresden Hbf',
#   'dateTime': '2021-10-27T09:07',
#   'origin': 'Berlin Hbf &#x0028;tief&#x0029;',
#   'track': '1',
#   'detailsId': '123303%2F60905%2F247936%2F82867%2F80%3fstation_evaId%3D8010085'},
#  {'name': 'ICE 1553',
#   'type': 'ICE',
#   'boardId': 8010085,
#   'stopId': 8010085,
#   'stopName': 'Dresden Hbf',
#   'dateTime': '2021-10-27T09:37',
#   'origin': 'Leipzig Hbf',
#   'track': '3',
#   'detailsId': '507285%2F171807%2F283370%2F27410%2F80%3fstation_evaId%3D8010085'},
#  {'name': 'IC 2173',
#   'type': 'IC',
#   'boardId': 8010085,
#   'stopId': 8010085,
#   'stopName': 'Dresden Hbf',
#   'dateTime': '2021-10-27T10:35',
#   'origin': 'Rostock Hbf',
#   'track': '3',
#   'detailsId': '917160%2F312271%2F289018%2F161211%2F80%3fstation_evaId%3D8010085'},
#  {'name': 'EC 176',
#   'type': 'EC',
#   'boardId': 8010085,
#   'stopId': 8010085,
#   'stopName': 'Dresden Hbf',
#   'dateTime': '2021-10-27T10:52',
#   'origin': 'Praha hl.n.',
#   'track': '12',
#   'detailsId': '977625%2F345741%2F834246%2F91248%2F80%3fstation_evaId%3D8010085'},
#  {'name': 'IC 2447',
#   'type': 'IC',
#   'boardId': 8010085,
#   'stopId': 8010085,
#   'stopName': 'Dresden Hbf',
#   'dateTime': '2021-10-27T11:00',
#   'origin': 'Hannover Hbf',
#   'track': '3',
#   'detailsId': '270783%2F99021%2F342310%2F80894%2F80%3fstation_evaId%3D8010085'},
#  {'name': 'EC 173',
#   'type': 'EC',
#   'boardId': 8010085,
#   'stopId': 8010085,
#   'stopName': 'Dresden Hbf',
#   'dateTime': '2021-10-27T11:07',
#   'origin': 'Berlin Hbf &#x0028;tief&#x0029;',
#   'track': '1',
#   'detailsId': '363273%2F140924%2F486296%2F122057%2F80%3fstation_evaId%3D8010085'},
#  {'name': 'ICE 1555',
#   'type': 'ICE',
#   'boardId': 8010085,
#   'stopId': 8010085,
#   'stopName': 'Dresden Hbf',
#   'dateTime': '2021-10-27T11:37',
#   'origin': 'Frankfurt&#x0028;Main&#x0029;Hbf',
#   'track': '3',
#   'detailsId': '923610%2F310611%2F208476%2F203632%2F80%3fstation_evaId%3D8010085'},
#  {'name': 'IC 2175',
#   'type': 'IC',
#   'boardId': 8010085,
#   'stopId': 8010085,
#   'stopName': 'Dresden Hbf',
#   'dateTime': '2021-10-27T12:35',
#   'origin': 'Warnemünde',
#   'track': '3',
#   'detailsId': '155733%2F58508%2F105046%2F612%2F80%3fstation_evaId%3D8010085'},
#  {'name': 'EC 174',
#   'type': 'EC',
#   'boardId': 8010085,
#   'stopId': 8010085,
#   'stopName': 'Dresden Hbf',
#   'dateTime': '2021-10-27T12:52',
#   'origin': 'Praha hl.n.',
#   'track': '12',
#   'detailsId': '770094%2F276564%2F773506%2F130056%2F80%3fstation_evaId%3D8010085'},
#  {'name': 'IC 2445',
#   'type': 'IC',
#   'boardId': 8010085,
#   'stopId': 8010085,
#   'stopName': 'Dresden Hbf',
#   'dateTime': '2021-10-27T13:00',
#   'origin': 'Köln Hbf',
#   'track': '3',
#   'detailsId': '716949%2F247702%2F799222%2F160628%2F80%3fstation_evaId%3D8010085'},
#  {'name': 'EC 379',
#   'type': 'EC',
#   'boardId': 8010085,
#   'stopId': 8010085,
#   'stopName': 'Dresden Hbf',
#   'dateTime': '2021-10-27T13:07',
#   'origin': 'Berlin Hbf &#x0028;tief&#x0029;',
#   'track': '1',
#   'detailsId': '887865%2F316953%2F710142%2F59116%2F80%3fstation_evaId%3D8010085'},
#  {'name': 'ICE 1557',
#   'type': 'ICE',
#   'boardId': 8010085,
#   'stopId': 8010085,
#   'stopName': 'Dresden Hbf',
#   'dateTime': '2021-10-27T13:37',
#   'origin': 'Frankfurt&#x0028;Main&#x0029;Hbf',
#   'track': '3',
#   'detailsId': '808512%2F272269%2F613934%2F37463%2F80%3fstation_evaId%3D8010085'},
#  {'name': 'IC 2177',
#   'type': 'IC',
#   'boardId': 8010085,
#   'stopId': 8010085,
#   'stopName': 'Dresden Hbf',
#   'dateTime': '2021-10-27T14:35',
#   'origin': 'Warnemünde',
#   'track': '3',
#   'detailsId': '305367%2F108418%2F708822%2F252622%2F80%3fstation_evaId%3D8010085'},
#  {'name': 'EC 378',
#   'type': 'EC',
#   'boardId': 8010085,
#   'stopId': 8010085,
#   'stopName': 'Dresden Hbf',
#   'dateTime': '2021-10-27T14:52',
#   'origin': 'Praha hl.n.',
#   'track': '12',
#   'detailsId': '362787%2F141906%2F249592%2F3867%2F80%3fstation_evaId%3D8010085'},
#  {'name': 'EC 175',
#   'type': 'EC',
#   'boardId': 8010085,
#   'stopId': 8010085,
#   'stopName': 'Dresden Hbf',
#   'dateTime': '2021-10-27T15:07',
#   'origin': 'Berlin Hbf &#x0028;tief&#x0029;',
#   'track': '1',
#   'detailsId': '171147%2F76910%2F70660%2F21719%2F80%3fstation_evaId%3D8010085'},
#  {'name': 'ICE 1559',
#   'type': 'ICE',
#   'boardId': 8010085,
#   'stopId': 8010085,
#   'stopName': 'Dresden Hbf',
#   'dateTime': '2021-10-27T15:37',
#   'origin': 'Frankfurt&#x0028;M&#x0029; Flughafen Fernbf',
#   'track': '3',
#   'detailsId': '331386%2F113260%2F560804%2F169940%2F80%3fstation_evaId%3D8010085'}]

# %% [markdown]
# ## All stations in Saxony

# %% [markdown]
# Extract all stations in Saxony, alongside with their EVA number. That number is used as an ID in the remainder of this application.

# %%
r = requests.get(station_overview_url, headers=base_headers, params={"federalstate": "sachsen"})
r
# Out:
# <Response [200]>

# %%
station_data = r.json()["result"]
stations = {s["name"]: s["evaNumbers"][0]["number"] for s in station_data}
stations
# Out:
# {'Adorf (Vogtl)': 8010001,
#  'Altenbach': 8011018,
#  'Kurort Altenberg (Erzgeb)': 8011019,
#  'Altmittweida': 8011033,
#  'Amtshainersdorf': 8011039,
#  'Leipzig Anger-Crottendorf': 8010008,
#  'Arnsdorf (b Dresden)': 8010006,
#  'Auerbach (Vogtl) Hp': 8011059,
#  'Auerbach (Vogtl) ob Bf': 8010011,
#  'Auerbach (Vogtl) unt Bf': 8010012,
#  'Bad Brambach': 8011068,
#  'Bad Elster': 8011072,
#  'Bad Lausick': 8011077,
#  'Bad Schandau': 8010022,
#  'Bärenhecke-Johnsbach': 8011091,
#  'Bärenstein (b Glashütte/Sachs)': 8011095,
#  'Barthmühle': 8011115,
#  'Bautzen': 8010026,
#  'Beilrode': 8011131,
#  'Belgershain': 8011132,
#  'Berthelsdorf (Erzgeb)': 8010044,
#  'Beucha': 8010046,
#  'Bienenmühle': 8011185,
#  'Bischheim-Gersdorf': 8011199,
#  'Bischofswerda': 8010049,
#  'Böhlen (b Leipzig)': 8013471,
#  'Böhlen Werke': 8011222,
#  'Borna (b Leipzig)': 8011242,
#  'Borsdorf (Sachs)': 8010059,
#  'Braunsdorf-Lichtenwalde': 8011257,
#  'Breitendorf': 8011264,
#  'Burgstädt': 8011297,
#  'Burkhardswalde-Maxen': 8011298,
#  'Chemnitz Hbf': 8010184,
#  'Chemnitz Kinderwaldstätte': 8011970,
#  'Chemnitz Mitte': 8011971,
#  'Chemnitz Süd': 8010185,
#  'Chemnitz-Borna Hp': 8011974,
#  'Chemnitz-Hilbersdorf Hp': 8013450,
#  'Chemnitz-Schönau': 8011979,
#  'Chemnitz-Siegmar': 8011980,
#  'Clausnitz': 8011315,
#  'Leipzig Coppiplatz': 8080840,
#  'Cossebaude': 8011320,
#  'Coswig (Bz Dresden)': 8010072,
#  'Cranzahl': 8010074,
#  'Crimmitschau': 8011325,
#  'Dahlen (Sachs)': 8011339,
#  'Delitzsch ob Bf': 8080280,
#  'Delitzsch unt Bf': 8010076,
#  'Demitz-Thumitz': 8011354,
#  'Deutzen': 8011371,
#  'Dittersbach (b Frankenberg/Sachs)': 8011385,
#  'Döbeln Hbf': 8010080,
#  'Doberschütz': 8011387,
#  'Dohna (Sachs)': 8011398,
#  'Dornreichenbach': 8011407,
#  'Dresden Grenzstraße': 8011417,
#  'Dresden Hbf': 8010085,
#  'Dresden Industriegelände': 8011418,
#  'Dresden Mitte': 8013444,
#  'Dresden-Cotta': 8011419,
#  'Dresden-Dobritz': 8011420,
#  'Dresden-Friedrichstadt': 8013475,
#  'Dresden-Kemnitz': 8011421,
#  'Dresden-Klotzsche': 8010088,
#  'Dresden-Neustadt': 8010089,
#  'Dresden-Niedersedlitz Hp': 8011422,
#  'Dresden-Pieschen': 8011423,
#  'Dresden-Plauen': 8013476,
#  'Dresden-Reick': 8011424,
#  'Dresden-Stetzsch': 8011425,
#  'Dresden-Strehlen': 8011426,
#  'Dresden-Trachau': 8011427,
#  'Dresden-Zschachwitz': 8011428,
#  'Dürrröhrsdorf': 8010091,
#  'Ebersbach (Sachs)': 8010092,
#  'Ebersbrunn': 8011446,
#  'Edle Krone': 8011451,
#  'Eibau': 8010094,
#  'Eilenburg': 8010095,
#  'Eilenburg Ost': 8010161,
#  'Ellefeld': 8011477,
#  'Elsterberg': 8011487,
#  'Elsterberg Kunstseidenwerk': 8011488,
#  'Leipzig Werkstättenstraße': 8011495,
#  'Erlau (Sachs)': 8011507,
#  'Falkenau (Sachs) Süd': 8011529,
#  'Falkenstein (Vogtl)': 8010106,
#  'Flöha': 8010108,
#  'Frankenberg (Sachs)': 8011553,
#  'Frankenberg (Sachs) Süd': 8011554,
#  'Frankenstein (Sachs)': 8011556,
#  'Frauenhain': 8011563,
#  'Freiberg (Sachs)': 8010115,
#  'Freital-Deuben': 8011569,
#  'Freital-Hainsberg': 8010116,
#  'Freital-Hainsberg West': 8011570,
#  'Freital-Potschappel': 8013445,
#  'Frohburg': 8011588,
#  'Markkleeberg-Gaschwitz': 8011598,
#  'Geising': 8011609,
#  'Geithain': 8010122,
#  'Gerichshain': 8011626,
#  'Gersdorf (b Görlitz)': 8011628,
#  'Glashütte (Sachs)': 8011636,
#  'Glaubitz (b Riesa)': 8011637,
#  'Glauchau (Sachs)': 8010129,
#  'Glauchau-Schönbörnchen': 8010130,
#  'Görlitz': 8010131,
#  'Görlitz-Weinhübel': 8011656,
#  'Goßdorf-Kohlmühle': 8011676,
#  'Grimma ob Bf': 8011705,
#  'Grobau': 8011709,
#  'Gröditz (b Riesa)': 8011712,
#  'Zwenkau-Großdalzig': 8013447,
#  'Großbothen': 8010144,
#  'Großdeuben': 8011745,
#  'Großenhain Cottb Bf': 8011749,
#  'Großharthau': 8011751,
#  'Großlehna': 8011753,
#  'Großpösna': 8011755,
#  'Großröhrsdorf': 8011758,
#  'Großschönau (Sachs)': 8011761,
#  'Großsteinberg': 8011763,
#  'Grüna (Sachs)': 8011770,
#  'Leipzig Grünauer Allee': 8011771,
#  'Grünbach': 8011773,
#  'Gutenfürst': 8011790,
#  'Hagenwerder': 8011799,
#  'Hähnichen': 8011795,
#  'Hainewalde': 8011801,
#  'Hainichen': 8011802,
#  'Hartmannmühle': 8011825,
#  'Heidenau': 8010163,
#  'Heidenau Süd': 8011843,
#  'Heidenau-Großsedlitz': 8011844,
#  'Helmsdorf (b Pirna)': 8011855,
#  'Herlasgrün': 8010166,
#  'Hermsdorf (b Dresden)': 8011861,
#  'Hirschfelde': 8011878,
#  'Hohenroda': 8011900,
#  'Hohenstein-Ernstthal': 8011904,
#  'Holzhau': 8011912,
#  'Leipzig-Holzhausen': 8011913,
#  'Hopfgarten (Sachs)': 8011914,
#  'Horka Pbf': 8010174,
#  'Hoyerswerda': 8010177,
#  'Hoyerswerda-Neustadt': 8011922,
#  'Hundsgrün': 8011928,
#  'Irfersgrün': 8011937,
#  'Jesewitz (b Leipzig)': 8011959,
#  'Jocketa': 8011963,
#  'Jößnitz': 8011966,
#  'Kamenz (Sachs)': 8011988,
#  'Kämmereiforst': 8011983,
#  'Leipzig Karlsruher Straße': 8010186,
#  'Kleinröhrsdorf': 8012036,
#  'Kleinschirma': 8012037,
#  'Klingenberg-Colmnitz': 8012044,
#  'Klingenthal': 8012045,
#  'Klitschmar': 8012046,
#  'Klitten': 8012047,
#  'Klosterbuch': 8012053,
#  'Leipzig Knautnaundorf': 8012059,
#  'Kodersdorf': 8012061,
#  'Königsbrück': 8012067,
#  'Königstein (Sächs Schweiz)': 8012072,
#  'Köttewitz': 8012079,
#  'Krensitz': 8012097,
#  'Krippen': 8012105,
#  'Krumhermsdorf': 8012113,
#  'Kubschütz': 8012115,
#  'Kühren': 8012117,
#  'Kürbitz': 8010040,
#  'Kurort Rathen (Kr Pirna)': 8012138,
#  'Kyhna': 8012141,
#  'Lampertswalde': 8012145,
#  'Langebrück (Sachs)': 8012150,
#  'Langenwolmsdorf': 8012163,
#  'Langenwolmsdorf Mitte': 8012164,
#  'Lauenstein (Sachs)': 8012170,
#  'Laußnitz': 8012174,
#  'Lauta (Niederlausitz)': 8012175,
#  'Lauterbach-Steinbach': 8012178,
#  'Leipzig Hbf': 8010205,
#  'Leipzig-Völkerschlachtdenkmal': 8012343,
#  'Leipzig-Connewitz': 8010206,
#  'Leipzig-Gohlis': 8012188,
#  'Leipzig-Heiterblick': 8012190,
#  'Leipzig-Knauthain': 8012192,
#  'Leipzig-Leutzsch': 8010207,
#  'Leipzig-Möckern': 8012193,
#  'Leipzig-Paunsdorf': 8010208,
#  'Leipzig-Plagwitz': 8010209,
#  'Leipzig-Stötteritz': 8012194,
#  'Leipzig-Thekla': 8012195,
#  'Leipzig-Wahren': 8012197,
#  'Leisnig': 8012198,
#  'Lengenfeld (Vogtl)': 8012203,
#  'Lichtenberg (Erzgeb)': 8012220,
#  'Lichtenstein (Sachs)': 8012223,
#  'Lichtentanne (Sachs)': 8012224,
#  'Leipzig-Liebertwolkwitz': 8012228,
#  'Limbach (Vogtl)': 8012231,
#  'Limmritz (Sachs)': 8012232,
#  'Leipzig-Lindenau': 8012236,
#  'Löbau (Sachs)': 8010212,
#  'Lobstädt': 8012241,
#  'Lohmen': 8012249,
#  'Lohsa': 8012250,
#  'Leipzig-Lützschena': 8012285,
#  'Machern (Sachs)': 8012284,
#  'Markkleeberg': 8012308,
#  'Markkleeberg Mitte': 8012309,
#  'Markkleeberg-Großstädteln': 8010228,
#  'Markranstädt': 8012311,
#  'Meerane': 8012323,
#  'Mehltheuer': 8010229,
#  'Meißen': 8012326,
#  'Meißen Triebischtal': 8012327,
#  'Leipzig Miltitz': 8012355,
#  'Leipzig Miltitzer Allee': 8012344,
#  'Mittelherwigsdorf (Sachs)': 8010234,
#  'Mittweida': 8012369,
#  'Mockrehna': 8012371,
#  'Leipzig-Mölkau': 8012375,
#  'Mosel': 8012388,
#  'Mücka': 8012391,
#  'Mühlbach (b Pirna)': 8012394,
#  'Mulda (Sachs)': 8012407,
#  'Muldenhütten': 8012408,
#  'Narsdorf': 8010238,
#  'Nassau (Erzgeb)': 8012412,
#  'Naunhof': 8012416,
#  'Netzschkau': 8012430,
#  'Neugersdorf': 8012454,
#  'Neukieritzsch': 8010243,
#  'Neukirch (Lausitz) Ost': 8012460,
#  'Neukirch (Lausitz) West': 8010400,
#  'Neukirchen-Wyhra': 8012463,
#  'Neumark (Sachs)': 8010244,
#  'Neusalza-Spremberg': 8012470,
#  'Neusörnewitz': 8012471,
#  'Neustadt (Sachs)': 8010249,
#  'Niederau': 8012482,
#  'Niederbobritzsch': 8012483,
#  'Niederoderwitz': 8012491,
#  'Niederschlottwitz': 8012497,
#  'Muldenberg Floßplatz': 8000273,
#  'Niederwartha': 8012503,
#  'Niederwiesa': 8010253,
#  'Niederwürschnitz': 8012505,
#  'Niesky': 8013493,
#  'Oberholz': 8012526,
#  'Oberlichtenau': 8012528,
#  'Oberoderwitz': 8010259,
#  'Oberoderwitz Oberdorf': 8012530,
#  'Oberrothenbach': 8012534,
#  'Oberschlottwitz': 8012535,
#  'Obervogelgesang (Kr Pirna)': 8012540,
#  'Oederan': 8012550,
#  'Oelsnitz (Erzgeb)': 8012553,
#  'Oelsnitz (Vogtl)': 8012554,
#  'Oschatz': 8013461,
#  'Ostrau': 8012576,
#  'Ottendorf (b Mittweida)': 8012593,
#  'Ottendorf-Okrilla Hp': 8012594,
#  'Ottendorf-Okrilla Nord': 8012595,
#  'Ottendorf-Okrilla Süd': 8012596,
#  'Otterwisch': 8012597,
#  'Pegau': 8010269,
#  'Petergrube': 8012623,
#  'Petershain': 8012628,
#  'Pirk': 8012639,
#  'Pirna': 8010272,
#  'Pirna-Copitz': 8012640,
#  'Plauen (Vogtl) ob Bf': 8010275,
#  'Plauen (Vogtl) West': 8012646,
#  'Pommritz': 8012660,
#  'Pönitz (b Leipzig)': 8012656,
#  'Porschdorf (Kr Pirna)': 8012662,
#  'Priestewitz': 8010285,
#  'Pulsnitz': 8012685,
#  'Putzkau': 8012688,
#  'Rackwitz (B Leipzig)': 8012697,
#  'Radeberg': 8012699,
#  'Radebeul Ost': 8010292,
#  'Radebeul-Kötzschenbroda': 8010293,
#  'Radebeul-Naundorf': 8013490,
#  'Radebeul-Weintraube': 8012700,
#  'Radebeul-Zitzschewig': 8012701,
#  'Rathmannsdorf (Kr Pirna)': 8012719,
#  'Raun': 8012724,
#  'Rechenberg': 8012727,
#  'Regis-Breitingen': 8012731,
#  'Reichenbach (Oberlausitz)': 8012738,
#  'Reichenbach (Vogtl) ob Bf': 8012739,
#  'Rentzschmühle': 8012751,
#  'Reuth (b Plauen/Vogtl)': 8012759,
#  'Riesa': 8010297,
#  'Rietschen': 8012767,
#  'Rodewisch': 8012775,
#  'Rödlitz-Hohndorf': 8012781,
#  'Leipzig-Rückmarsdorf': 8012817,
#  'Ruppertsgrün': 8012823,
#  'Schirgiswalde-Kirschau': 8012864,
#  'Schkeuditz': 8012865,
#  'Schleife': 8012870,
#  'Schmilka-Hirschmühle': 8012888,
#  'Schmölln (Oberlausitz)': 8012890,
#  'Schöna': 8012898,
#  'Schönberg (Vogtl)': 8010317,
#  'Schöneck (Vogtl)': 8012908,
#  'Schwarzkollm': 8012942,
#  'Schweikershain': 8012946,
#  'Schweinsburg-Culten': 8012947,
#  'Sebnitz (Sachs)': 8012959,
#  'Seerhausen': 8012975,
#  'Seitschen': 8012981,
#  'Leipzig-Sellerhausen': 8080930,
#  'Sohl': 8013002,
#  'Sohland': 8013003,
#  'St Egidien': 8010331,
#  'Stadt Wehlen (Sachs)': 8013022,
#  'Stauchitz': 8013029,
#  'Steina': 8013033,
#  'Steinpleis': 8010333,
#  'Nünchritz': 8012523,
#  'Stenn': 8013047,
#  'Stollberg (Sachs)': 8010337,
#  'Stolpen': 8013057,
#  'Allee-Center Leipzig': 8013070,
#  'Syrau': 8013080,
#  'Tanndorf': 8013087,
#  'Taubenheim (Spree)': 8013092,
#  'Taucha (b Leipzig)': 8013093,
#  'Tautenhain': 8013095,
#  'Tharandt': 8013114,
#  'Tiefenau': 8013124,
#  'Torgau': 8010351,
#  'Treuen': 8013144,
#  'Uhsmannsdorf': 8013165,
#  'Uhyst': 8013166,
#  'Ulbersdorf': 8013168,
#  'Voigtsgrün': 8013201,
#  'Waldheim': 8010359,
#  'Weesenstein': 8013247,
#  'Weickersdorf (Sachs)': 8013253,
#  'Weischlitz': 8010367,
#  'Weißwasser (Oberlausitz)': 8010370,
#  'Weixdorf': 8013268,
#  'Weixdorf Bad': 8013269,
#  'Werdau': 8010372,
#  'Werdau Nord': 8013280,
#  'Westewitz-Hochweitzschen': 8013295,
#  'Wilthen': 8010380,
#  'Wittgensdorf Mitte': 8013324,
#  'Wittgensdorf ob Bf': 8010383,
#  'Wülknitz': 8013348,
#  'Wurzen': 8013361,
#  'Bennewitz': 8013362,
#  'Wüstenbrand': 8010388,
#  'Zabeltitz': 8013368,
#  'Zeithain': 8013381,
#  'Zittau': 8010393,
#  'Zoblitz': 8013413,
#  'Zschaitz': 8013424,
#  'Zschortau': 8013428,
#  'Zwickau (Sachs) Hbf': 8010397,
#  'Zwickau-Pölbitz': 8013433,
#  'Zwota': 8013437,
#  'Zwota-Zechenbach': 8013436,
#  'Zwotental': 8010398,
#  'Leipzig Messe': 8012478,
#  'Flughafen Leipzig/Halle': 8012183,
#  'Dresden Flughafen': 8011399,
#  'Schöneck (Vogtl) Ferienpark': 8000343,
#  'Leipzig-Engelsdorf': 8011491,
#  'Görlitz-Rauschwalde': 8012869,
#  'Pirna-Copitz Nord': 8012641,
#  'Dresden Freiberger Straße': 8011431,
#  'Dresden Bischofsplatz': 8011416,
#  'Leipzig-Olbrichtstraße': 8012181,
#  'Schkeuditz West': 8012863,
#  'Leipzig-Slevogtstraße': 8012204,
#  'Leipzig Markt': 8012186,
#  'Leipzig Wilhelm-Leuschner-Platz': 8012202,
#  'Leipzig Bayerischer Bahnhof': 8012184,
#  'Leipzig MDR': 8012187,
#  'Plauen (Vogtl)-Straßberg': 8010336,
#  'Weinböhla Hp': 8013267,
#  'Leipzig Nord': 8012196,
#  'Leipzig Mockauer Straße': 8012273,
#  'Meißen Altstadt': 8012318,
#  'Plauen (Vogtl) Mitte': 8017442,
#  'Pulsnitz Süd': 8012686,
#  'Markkleeberg Nord': 8012304,
#  'Chemnitz-Küchwald': 8017050,
#  'Leipzig Essener Straße': 8012200}

# %%
len(stations)
# Out:
# 400

# %% [markdown]
# The total number of requests to fetch the complete timetables for all stations:

# %%
hours_per_day = 24
requests_per_minute = 20
total_requests = len(stations) * hours_per_day
total_fetch_time = total_requests / requests_per_minute

# %% [markdown]
# ## Fetch all connections of all stations

# %%
import itertools
import os
import time

hours = list(range(0, 24))
rate_limit = 20
base_dir = "timetables"
outfile_format = "timetable_{station}_{hour:02}.xml"
timetable_url_pattern = "{base}{station}/{date}/{hour:02}"

xml_headers = base_headers.copy()
xml_headers["Accept"] = "application/xml"

os.makedirs(base_dir, exist_ok=True)

# %%
station_evas = list(stations.values())

# %%
test_stations = [station_evas[i] for i in range(7)]
test_hours = list(range(15, 18))

# %%
timetable_idx = 0
timetable_combinations = list(itertools.product(station_evas, hours))
n_timetable_combinations = len(timetable_combinations)
error_combinations = []
for timetable in timetable_combinations:
    stat, hour = timetable
    timetable_idx += 1
    
    req_url = timetable_url_pattern.format(base=timetable_base_url, station=stat, date=today_short, hour=hour)
    r = requests.get(req_url, headers=xml_headers)
    
    if r.status_code != 200:
        print("Error on request", timetable_idx, "(station={}, hour={})".format(stat, hour), " code =", r.status_code)
        error_combinations.append({"station": stat, "hour": hour, "status": r.status_code})
    
    outfile_name = base_dir + "/" + outfile_format.format(station=stat, hour=hour)
    with open(outfile_name, "w") as outfile:
        outfile.write(r.text)
    
    if timetable_idx % rate_limit == 0:
        print(timetable_idx, "timetables (of", n_timetable_combinations, ") so far. Taking a break.")
        time.sleep(60)
# Out:
# 20 timetables (of 9600 ) so far. Taking a break.
# 40 timetables (of 9600 ) so far. Taking a break.
# 60 timetables (of 9600 ) so far. Taking a break.
# 80 timetables (of 9600 ) so far. Taking a break.
# 100 timetables (of 9600 ) so far. Taking a break.
# 120 timetables (of 9600 ) so far. Taking a break.
# 140 timetables (of 9600 ) so far. Taking a break.
# 160 timetables (of 9600 ) so far. Taking a break.
# 180 timetables (of 9600 ) so far. Taking a break.
# 200 timetables (of 9600 ) so far. Taking a break.
# 220 timetables (of 9600 ) so far. Taking a break.
# 240 timetables (of 9600 ) so far. Taking a break.
# 260 timetables (of 9600 ) so far. Taking a break.
# 280 timetables (of 9600 ) so far. Taking a break.
# 300 timetables (of 9600 ) so far. Taking a break.
# 320 timetables (of 9600 ) so far. Taking a break.
# 340 timetables (of 9600 ) so far. Taking a break.
# 360 timetables (of 9600 ) so far. Taking a break.
# 380 timetables (of 9600 ) so far. Taking a break.
# 400 timetables (of 9600 ) so far. Taking a break.
# 420 timetables (of 9600 ) so far. Taking a break.
# 440 timetables (of 9600 ) so far. Taking a break.
# Error on request 457 (station=8011132, hour=0)  code = 410
# 460 timetables (of 9600 ) so far. Taking a break.
# 480 timetables (of 9600 ) so far. Taking a break.
# Error on request 481 (station=8010044, hour=0)  code = 410
# 500 timetables (of 9600 ) so far. Taking a break.
# Error on request 505 (station=8010046, hour=0)  code = 410
# 520 timetables (of 9600 ) so far. Taking a break.
# Error on request 529 (station=8011185, hour=0)  code = 410
# 540 timetables (of 9600 ) so far. Taking a break.
# Error on request 553 (station=8011199, hour=0)  code = 410
# 560 timetables (of 9600 ) so far. Taking a break.
# Error on request 577 (station=8010049, hour=0)  code = 410
# 580 timetables (of 9600 ) so far. Taking a break.
# 600 timetables (of 9600 ) so far. Taking a break.
# Error on request 601 (station=8013471, hour=0)  code = 410
# 620 timetables (of 9600 ) so far. Taking a break.
# Error on request 625 (station=8011222, hour=0)  code = 410
# 640 timetables (of 9600 ) so far. Taking a break.
# Error on request 649 (station=8011242, hour=0)  code = 410
# 660 timetables (of 9600 ) so far. Taking a break.
# Error on request 673 (station=8010059, hour=0)  code = 410
# 680 timetables (of 9600 ) so far. Taking a break.
# Error on request 697 (station=8011257, hour=0)  code = 410
# 700 timetables (of 9600 ) so far. Taking a break.
# 720 timetables (of 9600 ) so far. Taking a break.
# Error on request 721 (station=8011264, hour=0)  code = 410
# 740 timetables (of 9600 ) so far. Taking a break.
# Error on request 745 (station=8011297, hour=0)  code = 410
# 760 timetables (of 9600 ) so far. Taking a break.
# Error on request 769 (station=8011298, hour=0)  code = 410
# 780 timetables (of 9600 ) so far. Taking a break.
# Error on request 793 (station=8010184, hour=0)  code = 410
# 800 timetables (of 9600 ) so far. Taking a break.
# Error on request 817 (station=8011970, hour=0)  code = 410
# 820 timetables (of 9600 ) so far. Taking a break.
# 840 timetables (of 9600 ) so far. Taking a break.
# Error on request 841 (station=8011971, hour=0)  code = 410
# 860 timetables (of 9600 ) so far. Taking a break.
# Error on request 865 (station=8010185, hour=0)  code = 410
# 880 timetables (of 9600 ) so far. Taking a break.
# Error on request 889 (station=8011974, hour=0)  code = 410
# 900 timetables (of 9600 ) so far. Taking a break.
# Error on request 913 (station=8013450, hour=0)  code = 410
# 920 timetables (of 9600 ) so far. Taking a break.
# Error on request 937 (station=8011979, hour=0)  code = 410
# 940 timetables (of 9600 ) so far. Taking a break.
# 960 timetables (of 9600 ) so far. Taking a break.
# Error on request 961 (station=8011980, hour=0)  code = 410
# 980 timetables (of 9600 ) so far. Taking a break.
# Error on request 985 (station=8011315, hour=0)  code = 410
# 1000 timetables (of 9600 ) so far. Taking a break.
# Error on request 1009 (station=8080840, hour=0)  code = 410
# 1020 timetables (of 9600 ) so far. Taking a break.
# Error on request 1033 (station=8011320, hour=0)  code = 410
# 1040 timetables (of 9600 ) so far. Taking a break.
# Error on request 1057 (station=8010072, hour=0)  code = 410
# 1060 timetables (of 9600 ) so far. Taking a break.
# 1080 timetables (of 9600 ) so far. Taking a break.
# Error on request 1081 (station=8010074, hour=0)  code = 410
# 1100 timetables (of 9600 ) so far. Taking a break.
# Error on request 1105 (station=8011325, hour=0)  code = 410
# 1120 timetables (of 9600 ) so far. Taking a break.
# Error on request 1129 (station=8011339, hour=0)  code = 410
# 1140 timetables (of 9600 ) so far. Taking a break.
# Error on request 1153 (station=8080280, hour=0)  code = 410
# 1160 timetables (of 9600 ) so far. Taking a break.
# Error on request 1177 (station=8010076, hour=0)  code = 410
# 1180 timetables (of 9600 ) so far. Taking a break.
# 1200 timetables (of 9600 ) so far. Taking a break.
# Error on request 1201 (station=8011354, hour=0)  code = 410
# 1220 timetables (of 9600 ) so far. Taking a break.
# Error on request 1225 (station=8011371, hour=0)  code = 410
# 1240 timetables (of 9600 ) so far. Taking a break.
# Error on request 1249 (station=8011385, hour=0)  code = 410
# 1260 timetables (of 9600 ) so far. Taking a break.
# Error on request 1273 (station=8010080, hour=0)  code = 410
# 1280 timetables (of 9600 ) so far. Taking a break.
# Error on request 1297 (station=8011387, hour=0)  code = 410
# 1300 timetables (of 9600 ) so far. Taking a break.
# 1320 timetables (of 9600 ) so far. Taking a break.
# Error on request 1321 (station=8011398, hour=0)  code = 410
# 1340 timetables (of 9600 ) so far. Taking a break.
# Error on request 1345 (station=8011407, hour=0)  code = 400
# Error on request 1346 (station=8011407, hour=1)  code = 400
# Error on request 1347 (station=8011407, hour=2)  code = 400
# Error on request 1348 (station=8011407, hour=3)  code = 400
# Error on request 1349 (station=8011407, hour=4)  code = 400
# Error on request 1350 (station=8011407, hour=5)  code = 400
# Error on request 1351 (station=8011407, hour=6)  code = 400
# Error on request 1352 (station=8011407, hour=7)  code = 400
# Error on request 1353 (station=8011407, hour=8)  code = 400
# Error on request 1354 (station=8011407, hour=9)  code = 400
# Error on request 1355 (station=8011407, hour=10)  code = 400
# Error on request 1356 (station=8011407, hour=11)  code = 400
# Error on request 1357 (station=8011407, hour=12)  code = 400
# Error on request 1358 (station=8011407, hour=13)  code = 400
# Error on request 1359 (station=8011407, hour=14)  code = 400
# Error on request 1360 (station=8011407, hour=15)  code = 400
# 1360 timetables (of 9600 ) so far. Taking a break.
# Error on request 1361 (station=8011407, hour=16)  code = 400
# Error on request 1362 (station=8011407, hour=17)  code = 400
# Error on request 1363 (station=8011407, hour=18)  code = 400
# Error on request 1364 (station=8011407, hour=19)  code = 400
# Error on request 1365 (station=8011407, hour=20)  code = 400
# Error on request 1366 (station=8011407, hour=21)  code = 400
# Error on request 1367 (station=8011407, hour=22)  code = 400
# Error on request 1368 (station=8011407, hour=23)  code = 400
# Error on request 1369 (station=8011417, hour=0)  code = 410
# 1380 timetables (of 9600 ) so far. Taking a break.
# Error on request 1393 (station=8010085, hour=0)  code = 410
# 1400 timetables (of 9600 ) so far. Taking a break.
# Error on request 1417 (station=8011418, hour=0)  code = 410
# 1420 timetables (of 9600 ) so far. Taking a break.
# 1440 timetables (of 9600 ) so far. Taking a break.
# Error on request 1441 (station=8013444, hour=0)  code = 410
# 1460 timetables (of 9600 ) so far. Taking a break.
# Error on request 1465 (station=8011419, hour=0)  code = 410
# 1480 timetables (of 9600 ) so far. Taking a break.
# Error on request 1489 (station=8011420, hour=0)  code = 410
# 1500 timetables (of 9600 ) so far. Taking a break.
# Error on request 1513 (station=8013475, hour=0)  code = 410
# 1520 timetables (of 9600 ) so far. Taking a break.
# Error on request 1537 (station=8011421, hour=0)  code = 410
# 1540 timetables (of 9600 ) so far. Taking a break.
# 1560 timetables (of 9600 ) so far. Taking a break.
# Error on request 1561 (station=8010088, hour=0)  code = 410
# 1580 timetables (of 9600 ) so far. Taking a break.
# Error on request 1585 (station=8010089, hour=0)  code = 410
# Error on request 1586 (station=8010089, hour=1)  code = 410
# 1600 timetables (of 9600 ) so far. Taking a break.
# Error on request 1609 (station=8011422, hour=0)  code = 410
# Error on request 1610 (station=8011422, hour=1)  code = 410
# 1620 timetables (of 9600 ) so far. Taking a break.
# Error on request 1633 (station=8011423, hour=0)  code = 410
# Error on request 1634 (station=8011423, hour=1)  code = 410
# 1640 timetables (of 9600 ) so far. Taking a break.
# Error on request 1657 (station=8013476, hour=0)  code = 410
# Error on request 1658 (station=8013476, hour=1)  code = 410
# 1660 timetables (of 9600 ) so far. Taking a break.
# 1680 timetables (of 9600 ) so far. Taking a break.
# Error on request 1681 (station=8011424, hour=0)  code = 410
# Error on request 1682 (station=8011424, hour=1)  code = 410
# 1700 timetables (of 9600 ) so far. Taking a break.
# Error on request 1705 (station=8011425, hour=0)  code = 410
# Error on request 1706 (station=8011425, hour=1)  code = 410
# 1720 timetables (of 9600 ) so far. Taking a break.
# Error on request 1729 (station=8011426, hour=0)  code = 410
# Error on request 1730 (station=8011426, hour=1)  code = 410
# 1740 timetables (of 9600 ) so far. Taking a break.
# Error on request 1753 (station=8011427, hour=0)  code = 410
# Error on request 1754 (station=8011427, hour=1)  code = 410
# 1760 timetables (of 9600 ) so far. Taking a break.
# Error on request 1777 (station=8011428, hour=0)  code = 410
# Error on request 1778 (station=8011428, hour=1)  code = 410
# 1780 timetables (of 9600 ) so far. Taking a break.
# 1800 timetables (of 9600 ) so far. Taking a break.
# Error on request 1801 (station=8010091, hour=0)  code = 410
# Error on request 1802 (station=8010091, hour=1)  code = 410
# 1820 timetables (of 9600 ) so far. Taking a break.
# Error on request 1825 (station=8010092, hour=0)  code = 410
# Error on request 1826 (station=8010092, hour=1)  code = 410
# 1840 timetables (of 9600 ) so far. Taking a break.
# Error on request 1849 (station=8011446, hour=0)  code = 410
# Error on request 1850 (station=8011446, hour=1)  code = 410
# 1860 timetables (of 9600 ) so far. Taking a break.
# Error on request 1873 (station=8011451, hour=0)  code = 410
# Error on request 1874 (station=8011451, hour=1)  code = 410
# 1880 timetables (of 9600 ) so far. Taking a break.
# Error on request 1897 (station=8010094, hour=0)  code = 410
# Error on request 1898 (station=8010094, hour=1)  code = 410
# 1900 timetables (of 9600 ) so far. Taking a break.
# 1920 timetables (of 9600 ) so far. Taking a break.
# Error on request 1921 (station=8010095, hour=0)  code = 410
# Error on request 1922 (station=8010095, hour=1)  code = 410
# 1940 timetables (of 9600 ) so far. Taking a break.
# Error on request 1945 (station=8010161, hour=0)  code = 410
# Error on request 1946 (station=8010161, hour=1)  code = 410
# 1960 timetables (of 9600 ) so far. Taking a break.
# Error on request 1969 (station=8011477, hour=0)  code = 410
# Error on request 1970 (station=8011477, hour=1)  code = 410
# 1980 timetables (of 9600 ) so far. Taking a break.
# Error on request 1993 (station=8011487, hour=0)  code = 410
# Error on request 1994 (station=8011487, hour=1)  code = 410
# 2000 timetables (of 9600 ) so far. Taking a break.
# Error on request 2017 (station=8011488, hour=0)  code = 410
# Error on request 2018 (station=8011488, hour=1)  code = 410
# 2020 timetables (of 9600 ) so far. Taking a break.
# 2040 timetables (of 9600 ) so far. Taking a break.
# Error on request 2041 (station=8011495, hour=0)  code = 410
# Error on request 2042 (station=8011495, hour=1)  code = 410
# 2060 timetables (of 9600 ) so far. Taking a break.
# Error on request 2065 (station=8011507, hour=0)  code = 410
# Error on request 2066 (station=8011507, hour=1)  code = 410
# 2080 timetables (of 9600 ) so far. Taking a break.
# Error on request 2089 (station=8011529, hour=0)  code = 410
# Error on request 2090 (station=8011529, hour=1)  code = 410
# 2100 timetables (of 9600 ) so far. Taking a break.
# Error on request 2113 (station=8010106, hour=0)  code = 410
# Error on request 2114 (station=8010106, hour=1)  code = 410
# 2120 timetables (of 9600 ) so far. Taking a break.
# Error on request 2137 (station=8010108, hour=0)  code = 410
# Error on request 2138 (station=8010108, hour=1)  code = 410
# 2140 timetables (of 9600 ) so far. Taking a break.
# 2160 timetables (of 9600 ) so far. Taking a break.
# Error on request 2161 (station=8011553, hour=0)  code = 410
# Error on request 2162 (station=8011553, hour=1)  code = 410
# 2180 timetables (of 9600 ) so far. Taking a break.
# Error on request 2185 (station=8011554, hour=0)  code = 410
# Error on request 2186 (station=8011554, hour=1)  code = 410
# 2200 timetables (of 9600 ) so far. Taking a break.
# Error on request 2209 (station=8011556, hour=0)  code = 410
# Error on request 2210 (station=8011556, hour=1)  code = 410
# 2220 timetables (of 9600 ) so far. Taking a break.
# Error on request 2233 (station=8011563, hour=0)  code = 410
# Error on request 2234 (station=8011563, hour=1)  code = 410
# 2240 timetables (of 9600 ) so far. Taking a break.
# Error on request 2257 (station=8010115, hour=0)  code = 410
# Error on request 2258 (station=8010115, hour=1)  code = 410
# 2260 timetables (of 9600 ) so far. Taking a break.
# 2280 timetables (of 9600 ) so far. Taking a break.
# Error on request 2281 (station=8011569, hour=0)  code = 410
# Error on request 2282 (station=8011569, hour=1)  code = 410
# 2300 timetables (of 9600 ) so far. Taking a break.
# Error on request 2305 (station=8010116, hour=0)  code = 410
# Error on request 2306 (station=8010116, hour=1)  code = 410
# 2320 timetables (of 9600 ) so far. Taking a break.
# Error on request 2329 (station=8011570, hour=0)  code = 410
# Error on request 2330 (station=8011570, hour=1)  code = 410
# 2340 timetables (of 9600 ) so far. Taking a break.
# Error on request 2353 (station=8013445, hour=0)  code = 410
# Error on request 2354 (station=8013445, hour=1)  code = 410
# 2360 timetables (of 9600 ) so far. Taking a break.
# Error on request 2377 (station=8011588, hour=0)  code = 410
# Error on request 2378 (station=8011588, hour=1)  code = 410
# 2380 timetables (of 9600 ) so far. Taking a break.
# 2400 timetables (of 9600 ) so far. Taking a break.
# Error on request 2401 (station=8011598, hour=0)  code = 410
# Error on request 2402 (station=8011598, hour=1)  code = 410
# 2420 timetables (of 9600 ) so far. Taking a break.
# Error on request 2425 (station=8011609, hour=0)  code = 410
# Error on request 2426 (station=8011609, hour=1)  code = 410
# 2440 timetables (of 9600 ) so far. Taking a break.
# Error on request 2449 (station=8010122, hour=0)  code = 410
# Error on request 2450 (station=8010122, hour=1)  code = 410
# 2460 timetables (of 9600 ) so far. Taking a break.
# Error on request 2473 (station=8011626, hour=0)  code = 410
# Error on request 2474 (station=8011626, hour=1)  code = 410
# 2480 timetables (of 9600 ) so far. Taking a break.
# Error on request 2497 (station=8011628, hour=0)  code = 410
# Error on request 2498 (station=8011628, hour=1)  code = 410
# 2500 timetables (of 9600 ) so far. Taking a break.
# 2520 timetables (of 9600 ) so far. Taking a break.
# Error on request 2521 (station=8011636, hour=0)  code = 410
# Error on request 2522 (station=8011636, hour=1)  code = 410
# 2540 timetables (of 9600 ) so far. Taking a break.
# Error on request 2545 (station=8011637, hour=0)  code = 410
# Error on request 2546 (station=8011637, hour=1)  code = 410
# 2560 timetables (of 9600 ) so far. Taking a break.
# Error on request 2569 (station=8010129, hour=0)  code = 410
# Error on request 2570 (station=8010129, hour=1)  code = 410
# 2580 timetables (of 9600 ) so far. Taking a break.
# Error on request 2593 (station=8010130, hour=0)  code = 410
# Error on request 2594 (station=8010130, hour=1)  code = 410
# 2600 timetables (of 9600 ) so far. Taking a break.
# Error on request 2617 (station=8010131, hour=0)  code = 410
# Error on request 2618 (station=8010131, hour=1)  code = 410
# 2620 timetables (of 9600 ) so far. Taking a break.
# 2640 timetables (of 9600 ) so far. Taking a break.
# Error on request 2641 (station=8011656, hour=0)  code = 410
# Error on request 2642 (station=8011656, hour=1)  code = 410
# 2660 timetables (of 9600 ) so far. Taking a break.
# Error on request 2665 (station=8011676, hour=0)  code = 410
# Error on request 2666 (station=8011676, hour=1)  code = 410
# 2680 timetables (of 9600 ) so far. Taking a break.
# Error on request 2689 (station=8011705, hour=0)  code = 410
# Error on request 2690 (station=8011705, hour=1)  code = 410
# 2700 timetables (of 9600 ) so far. Taking a break.
# Error on request 2713 (station=8011709, hour=0)  code = 410
# Error on request 2714 (station=8011709, hour=1)  code = 410
# 2720 timetables (of 9600 ) so far. Taking a break.
# Error on request 2737 (station=8011712, hour=0)  code = 410
# Error on request 2738 (station=8011712, hour=1)  code = 410
# Error on request 2739 (station=8011712, hour=2)  code = 410
# 2740 timetables (of 9600 ) so far. Taking a break.
# 2760 timetables (of 9600 ) so far. Taking a break.
# Error on request 2761 (station=8013447, hour=0)  code = 410
# Error on request 2762 (station=8013447, hour=1)  code = 410
# Error on request 2763 (station=8013447, hour=2)  code = 410
# 2780 timetables (of 9600 ) so far. Taking a break.
# Error on request 2785 (station=8010144, hour=0)  code = 410
# Error on request 2786 (station=8010144, hour=1)  code = 410
# Error on request 2787 (station=8010144, hour=2)  code = 410
# 2800 timetables (of 9600 ) so far. Taking a break.
# Error on request 2809 (station=8011745, hour=0)  code = 410
# Error on request 2810 (station=8011745, hour=1)  code = 410
# Error on request 2811 (station=8011745, hour=2)  code = 410
# 2820 timetables (of 9600 ) so far. Taking a break.
# Error on request 2833 (station=8011749, hour=0)  code = 410
# Error on request 2834 (station=8011749, hour=1)  code = 410
# Error on request 2835 (station=8011749, hour=2)  code = 410
# 2840 timetables (of 9600 ) so far. Taking a break.
# Error on request 2857 (station=8011751, hour=0)  code = 410
# Error on request 2858 (station=8011751, hour=1)  code = 410
# Error on request 2859 (station=8011751, hour=2)  code = 410
# 2860 timetables (of 9600 ) so far. Taking a break.
# 2880 timetables (of 9600 ) so far. Taking a break.
# Error on request 2881 (station=8011753, hour=0)  code = 410
# Error on request 2882 (station=8011753, hour=1)  code = 410
# Error on request 2883 (station=8011753, hour=2)  code = 410
# 2900 timetables (of 9600 ) so far. Taking a break.
# Error on request 2905 (station=8011755, hour=0)  code = 410
# Error on request 2906 (station=8011755, hour=1)  code = 410
# Error on request 2907 (station=8011755, hour=2)  code = 410
# 2920 timetables (of 9600 ) so far. Taking a break.
# Error on request 2929 (station=8011758, hour=0)  code = 410
# Error on request 2930 (station=8011758, hour=1)  code = 410
# Error on request 2931 (station=8011758, hour=2)  code = 410
# 2940 timetables (of 9600 ) so far. Taking a break.
# Error on request 2953 (station=8011761, hour=0)  code = 410
# Error on request 2954 (station=8011761, hour=1)  code = 410
# Error on request 2955 (station=8011761, hour=2)  code = 410
# 2960 timetables (of 9600 ) so far. Taking a break.
# Error on request 2977 (station=8011763, hour=0)  code = 410
# Error on request 2978 (station=8011763, hour=1)  code = 410
# Error on request 2979 (station=8011763, hour=2)  code = 410
# 2980 timetables (of 9600 ) so far. Taking a break.
# 3000 timetables (of 9600 ) so far. Taking a break.
# Error on request 3001 (station=8011770, hour=0)  code = 410
# Error on request 3002 (station=8011770, hour=1)  code = 410
# Error on request 3003 (station=8011770, hour=2)  code = 410
# 3020 timetables (of 9600 ) so far. Taking a break.
# Error on request 3025 (station=8011771, hour=0)  code = 410
# Error on request 3026 (station=8011771, hour=1)  code = 410
# Error on request 3027 (station=8011771, hour=2)  code = 410
# 3040 timetables (of 9600 ) so far. Taking a break.
# Error on request 3049 (station=8011773, hour=0)  code = 410
# Error on request 3050 (station=8011773, hour=1)  code = 410
# Error on request 3051 (station=8011773, hour=2)  code = 410
# 3060 timetables (of 9600 ) so far. Taking a break.
# Error on request 3073 (station=8011790, hour=0)  code = 410
# Error on request 3074 (station=8011790, hour=1)  code = 410
# Error on request 3075 (station=8011790, hour=2)  code = 410
# 3080 timetables (of 9600 ) so far. Taking a break.
# Error on request 3097 (station=8011799, hour=0)  code = 410
# Error on request 3098 (station=8011799, hour=1)  code = 410
# Error on request 3099 (station=8011799, hour=2)  code = 410
# 3100 timetables (of 9600 ) so far. Taking a break.
# 3120 timetables (of 9600 ) so far. Taking a break.
# Error on request 3121 (station=8011795, hour=0)  code = 410
# Error on request 3122 (station=8011795, hour=1)  code = 410
# Error on request 3123 (station=8011795, hour=2)  code = 410
# 3140 timetables (of 9600 ) so far. Taking a break.
# Error on request 3145 (station=8011801, hour=0)  code = 410
# Error on request 3146 (station=8011801, hour=1)  code = 410
# Error on request 3147 (station=8011801, hour=2)  code = 410
# 3160 timetables (of 9600 ) so far. Taking a break.
# Error on request 3169 (station=8011802, hour=0)  code = 410
# Error on request 3170 (station=8011802, hour=1)  code = 410
# Error on request 3171 (station=8011802, hour=2)  code = 410
# 3180 timetables (of 9600 ) so far. Taking a break.
# Error on request 3193 (station=8011825, hour=0)  code = 410
# Error on request 3194 (station=8011825, hour=1)  code = 410
# Error on request 3195 (station=8011825, hour=2)  code = 410
# 3200 timetables (of 9600 ) so far. Taking a break.
# Error on request 3217 (station=8010163, hour=0)  code = 410
# Error on request 3218 (station=8010163, hour=1)  code = 410
# Error on request 3219 (station=8010163, hour=2)  code = 410
# 3220 timetables (of 9600 ) so far. Taking a break.
# 3240 timetables (of 9600 ) so far. Taking a break.
# Error on request 3241 (station=8011843, hour=0)  code = 410
# Error on request 3242 (station=8011843, hour=1)  code = 410
# Error on request 3243 (station=8011843, hour=2)  code = 410
# 3260 timetables (of 9600 ) so far. Taking a break.
# Error on request 3265 (station=8011844, hour=0)  code = 410
# Error on request 3266 (station=8011844, hour=1)  code = 410
# Error on request 3267 (station=8011844, hour=2)  code = 410
# 3280 timetables (of 9600 ) so far. Taking a break.
# Error on request 3289 (station=8011855, hour=0)  code = 410
# Error on request 3290 (station=8011855, hour=1)  code = 410
# Error on request 3291 (station=8011855, hour=2)  code = 410
# 3300 timetables (of 9600 ) so far. Taking a break.
# Error on request 3313 (station=8010166, hour=0)  code = 410
# Error on request 3314 (station=8010166, hour=1)  code = 410
# Error on request 3315 (station=8010166, hour=2)  code = 410
# 3320 timetables (of 9600 ) so far. Taking a break.
# Error on request 3337 (station=8011861, hour=0)  code = 410
# Error on request 3338 (station=8011861, hour=1)  code = 410
# Error on request 3339 (station=8011861, hour=2)  code = 410
# 3340 timetables (of 9600 ) so far. Taking a break.
# 3360 timetables (of 9600 ) so far. Taking a break.
# Error on request 3361 (station=8011878, hour=0)  code = 410
# Error on request 3362 (station=8011878, hour=1)  code = 410
# Error on request 3363 (station=8011878, hour=2)  code = 410
# 3380 timetables (of 9600 ) so far. Taking a break.
# Error on request 3385 (station=8011900, hour=0)  code = 410
# Error on request 3386 (station=8011900, hour=1)  code = 410
# Error on request 3387 (station=8011900, hour=2)  code = 410
# 3400 timetables (of 9600 ) so far. Taking a break.
# Error on request 3409 (station=8011904, hour=0)  code = 410
# Error on request 3410 (station=8011904, hour=1)  code = 410
# Error on request 3411 (station=8011904, hour=2)  code = 410
# 3420 timetables (of 9600 ) so far. Taking a break.
# Error on request 3433 (station=8011912, hour=0)  code = 410
# Error on request 3434 (station=8011912, hour=1)  code = 410
# Error on request 3435 (station=8011912, hour=2)  code = 410
# 3440 timetables (of 9600 ) so far. Taking a break.
# Error on request 3457 (station=8011913, hour=0)  code = 410
# Error on request 3458 (station=8011913, hour=1)  code = 410
# Error on request 3459 (station=8011913, hour=2)  code = 410
# 3460 timetables (of 9600 ) so far. Taking a break.
# 3480 timetables (of 9600 ) so far. Taking a break.
# Error on request 3481 (station=8011914, hour=0)  code = 410
# Error on request 3482 (station=8011914, hour=1)  code = 410
# Error on request 3483 (station=8011914, hour=2)  code = 410
# 3500 timetables (of 9600 ) so far. Taking a break.
# Error on request 3505 (station=8010174, hour=0)  code = 410
# Error on request 3506 (station=8010174, hour=1)  code = 410
# Error on request 3507 (station=8010174, hour=2)  code = 410
# 3520 timetables (of 9600 ) so far. Taking a break.
# Error on request 3529 (station=8010177, hour=0)  code = 410
# Error on request 3530 (station=8010177, hour=1)  code = 410
# Error on request 3531 (station=8010177, hour=2)  code = 410
# 3540 timetables (of 9600 ) so far. Taking a break.
# Error on request 3553 (station=8011922, hour=0)  code = 410
# Error on request 3554 (station=8011922, hour=1)  code = 410
# Error on request 3555 (station=8011922, hour=2)  code = 410
# 3560 timetables (of 9600 ) so far. Taking a break.
# Error on request 3577 (station=8011928, hour=0)  code = 410
# Error on request 3578 (station=8011928, hour=1)  code = 410
# Error on request 3579 (station=8011928, hour=2)  code = 410
# 3580 timetables (of 9600 ) so far. Taking a break.
# 3600 timetables (of 9600 ) so far. Taking a break.
# Error on request 3601 (station=8011937, hour=0)  code = 410
# Error on request 3602 (station=8011937, hour=1)  code = 410
# Error on request 3603 (station=8011937, hour=2)  code = 410
# 3620 timetables (of 9600 ) so far. Taking a break.
# Error on request 3625 (station=8011959, hour=0)  code = 410
# Error on request 3626 (station=8011959, hour=1)  code = 410
# Error on request 3627 (station=8011959, hour=2)  code = 410
# 3640 timetables (of 9600 ) so far. Taking a break.
# Error on request 3649 (station=8011963, hour=0)  code = 410
# Error on request 3650 (station=8011963, hour=1)  code = 410
# Error on request 3651 (station=8011963, hour=2)  code = 410
# 3660 timetables (of 9600 ) so far. Taking a break.
# Error on request 3673 (station=8011966, hour=0)  code = 410
# Error on request 3674 (station=8011966, hour=1)  code = 410
# Error on request 3675 (station=8011966, hour=2)  code = 410
# 3680 timetables (of 9600 ) so far. Taking a break.
# Error on request 3697 (station=8011988, hour=0)  code = 410
# Error on request 3698 (station=8011988, hour=1)  code = 410
# Error on request 3699 (station=8011988, hour=2)  code = 410
# 3700 timetables (of 9600 ) so far. Taking a break.
# 3720 timetables (of 9600 ) so far. Taking a break.
# Error on request 3721 (station=8011983, hour=0)  code = 410
# Error on request 3722 (station=8011983, hour=1)  code = 410
# Error on request 3723 (station=8011983, hour=2)  code = 410
# 3740 timetables (of 9600 ) so far. Taking a break.
# Error on request 3745 (station=8010186, hour=0)  code = 410
# Error on request 3746 (station=8010186, hour=1)  code = 410
# Error on request 3747 (station=8010186, hour=2)  code = 410
# 3760 timetables (of 9600 ) so far. Taking a break.
# Error on request 3769 (station=8012036, hour=0)  code = 410
# Error on request 3770 (station=8012036, hour=1)  code = 410
# Error on request 3771 (station=8012036, hour=2)  code = 410
# 3780 timetables (of 9600 ) so far. Taking a break.
# Error on request 3793 (station=8012037, hour=0)  code = 410
# Error on request 3794 (station=8012037, hour=1)  code = 410
# Error on request 3795 (station=8012037, hour=2)  code = 410
# 3800 timetables (of 9600 ) so far. Taking a break.
# Error on request 3817 (station=8012044, hour=0)  code = 410
# Error on request 3818 (station=8012044, hour=1)  code = 410
# Error on request 3819 (station=8012044, hour=2)  code = 410
# 3820 timetables (of 9600 ) so far. Taking a break.
# 3840 timetables (of 9600 ) so far. Taking a break.
# Error on request 3841 (station=8012045, hour=0)  code = 410
# Error on request 3842 (station=8012045, hour=1)  code = 410
# Error on request 3843 (station=8012045, hour=2)  code = 410
# Error on request 3844 (station=8012045, hour=3)  code = 410
# 3860 timetables (of 9600 ) so far. Taking a break.
# Error on request 3865 (station=8012046, hour=0)  code = 410
# Error on request 3866 (station=8012046, hour=1)  code = 410
# Error on request 3867 (station=8012046, hour=2)  code = 410
# Error on request 3868 (station=8012046, hour=3)  code = 410
# 3880 timetables (of 9600 ) so far. Taking a break.
# Error on request 3889 (station=8012047, hour=0)  code = 410
# Error on request 3890 (station=8012047, hour=1)  code = 410
# Error on request 3891 (station=8012047, hour=2)  code = 410
# Error on request 3892 (station=8012047, hour=3)  code = 410
# 3900 timetables (of 9600 ) so far. Taking a break.
# Error on request 3913 (station=8012053, hour=0)  code = 410
# Error on request 3914 (station=8012053, hour=1)  code = 410
# Error on request 3915 (station=8012053, hour=2)  code = 410
# Error on request 3916 (station=8012053, hour=3)  code = 410
# 3920 timetables (of 9600 ) so far. Taking a break.
# Error on request 3937 (station=8012059, hour=0)  code = 400
# Error on request 3938 (station=8012059, hour=1)  code = 400
# Error on request 3939 (station=8012059, hour=2)  code = 400
# Error on request 3940 (station=8012059, hour=3)  code = 400
# 3940 timetables (of 9600 ) so far. Taking a break.
# Error on request 3941 (station=8012059, hour=4)  code = 400
# Error on request 3942 (station=8012059, hour=5)  code = 400
# Error on request 3943 (station=8012059, hour=6)  code = 400
# Error on request 3944 (station=8012059, hour=7)  code = 400
# Error on request 3945 (station=8012059, hour=8)  code = 400
# Error on request 3946 (station=8012059, hour=9)  code = 400
# Error on request 3947 (station=8012059, hour=10)  code = 400
# Error on request 3948 (station=8012059, hour=11)  code = 400
# Error on request 3949 (station=8012059, hour=12)  code = 400
# Error on request 3950 (station=8012059, hour=13)  code = 400
# Error on request 3951 (station=8012059, hour=14)  code = 400
# Error on request 3952 (station=8012059, hour=15)  code = 400
# Error on request 3953 (station=8012059, hour=16)  code = 400
# Error on request 3954 (station=8012059, hour=17)  code = 400
# Error on request 3955 (station=8012059, hour=18)  code = 400
# Error on request 3956 (station=8012059, hour=19)  code = 400
# Error on request 3957 (station=8012059, hour=20)  code = 400
# Error on request 3958 (station=8012059, hour=21)  code = 400
# Error on request 3959 (station=8012059, hour=22)  code = 400
# Error on request 3960 (station=8012059, hour=23)  code = 400
# 3960 timetables (of 9600 ) so far. Taking a break.
# Error on request 3961 (station=8012061, hour=0)  code = 410
# Error on request 3962 (station=8012061, hour=1)  code = 410
# Error on request 3963 (station=8012061, hour=2)  code = 410
# Error on request 3964 (station=8012061, hour=3)  code = 410
# 3980 timetables (of 9600 ) so far. Taking a break.
# Error on request 3985 (station=8012067, hour=0)  code = 410
# Error on request 3986 (station=8012067, hour=1)  code = 410
# Error on request 3987 (station=8012067, hour=2)  code = 410
# Error on request 3988 (station=8012067, hour=3)  code = 410
# 4000 timetables (of 9600 ) so far. Taking a break.
# Error on request 4009 (station=8012072, hour=0)  code = 410
# Error on request 4010 (station=8012072, hour=1)  code = 410
# Error on request 4011 (station=8012072, hour=2)  code = 410
# Error on request 4012 (station=8012072, hour=3)  code = 410
# 4020 timetables (of 9600 ) so far. Taking a break.
# Error on request 4033 (station=8012079, hour=0)  code = 410
# Error on request 4034 (station=8012079, hour=1)  code = 410
# Error on request 4035 (station=8012079, hour=2)  code = 410
# Error on request 4036 (station=8012079, hour=3)  code = 410
# 4040 timetables (of 9600 ) so far. Taking a break.
# Error on request 4057 (station=8012097, hour=0)  code = 410
# Error on request 4058 (station=8012097, hour=1)  code = 410
# Error on request 4059 (station=8012097, hour=2)  code = 410
# Error on request 4060 (station=8012097, hour=3)  code = 410
# 4060 timetables (of 9600 ) so far. Taking a break.
# 4080 timetables (of 9600 ) so far. Taking a break.
# Error on request 4081 (station=8012105, hour=0)  code = 410
# Error on request 4082 (station=8012105, hour=1)  code = 410
# Error on request 4083 (station=8012105, hour=2)  code = 410
# Error on request 4084 (station=8012105, hour=3)  code = 410
# 4100 timetables (of 9600 ) so far. Taking a break.
# Error on request 4105 (station=8012113, hour=0)  code = 410
# Error on request 4106 (station=8012113, hour=1)  code = 410
# Error on request 4107 (station=8012113, hour=2)  code = 410
# Error on request 4108 (station=8012113, hour=3)  code = 410
# 4120 timetables (of 9600 ) so far. Taking a break.
# Error on request 4129 (station=8012115, hour=0)  code = 410
# Error on request 4130 (station=8012115, hour=1)  code = 410
# Error on request 4131 (station=8012115, hour=2)  code = 410
# Error on request 4132 (station=8012115, hour=3)  code = 410
# 4140 timetables (of 9600 ) so far. Taking a break.
# Error on request 4153 (station=8012117, hour=0)  code = 410
# Error on request 4154 (station=8012117, hour=1)  code = 410
# Error on request 4155 (station=8012117, hour=2)  code = 410
# Error on request 4156 (station=8012117, hour=3)  code = 410
# 4160 timetables (of 9600 ) so far. Taking a break.
# Error on request 4177 (station=8010040, hour=0)  code = 410
# Error on request 4178 (station=8010040, hour=1)  code = 410
# Error on request 4179 (station=8010040, hour=2)  code = 410
# Error on request 4180 (station=8010040, hour=3)  code = 410
# 4180 timetables (of 9600 ) so far. Taking a break.
# 4200 timetables (of 9600 ) so far. Taking a break.
# Error on request 4201 (station=8012138, hour=0)  code = 410
# Error on request 4202 (station=8012138, hour=1)  code = 410
# Error on request 4203 (station=8012138, hour=2)  code = 410
# Error on request 4204 (station=8012138, hour=3)  code = 410
# 4220 timetables (of 9600 ) so far. Taking a break.
# Error on request 4225 (station=8012141, hour=0)  code = 410
# Error on request 4226 (station=8012141, hour=1)  code = 410
# Error on request 4227 (station=8012141, hour=2)  code = 410
# Error on request 4228 (station=8012141, hour=3)  code = 410
# 4240 timetables (of 9600 ) so far. Taking a break.
# Error on request 4249 (station=8012145, hour=0)  code = 410
# Error on request 4250 (station=8012145, hour=1)  code = 410
# Error on request 4251 (station=8012145, hour=2)  code = 410
# Error on request 4252 (station=8012145, hour=3)  code = 410
# 4260 timetables (of 9600 ) so far. Taking a break.
# Error on request 4273 (station=8012150, hour=0)  code = 410
# Error on request 4274 (station=8012150, hour=1)  code = 410
# Error on request 4275 (station=8012150, hour=2)  code = 410
# Error on request 4276 (station=8012150, hour=3)  code = 410
# 4280 timetables (of 9600 ) so far. Taking a break.
# Error on request 4297 (station=8012163, hour=0)  code = 410
# Error on request 4298 (station=8012163, hour=1)  code = 410
# Error on request 4299 (station=8012163, hour=2)  code = 410
# Error on request 4300 (station=8012163, hour=3)  code = 410
# 4300 timetables (of 9600 ) so far. Taking a break.
# 4320 timetables (of 9600 ) so far. Taking a break.
# Error on request 4321 (station=8012164, hour=0)  code = 410
# Error on request 4322 (station=8012164, hour=1)  code = 410
# Error on request 4323 (station=8012164, hour=2)  code = 410
# Error on request 4324 (station=8012164, hour=3)  code = 410
# 4340 timetables (of 9600 ) so far. Taking a break.
# Error on request 4345 (station=8012170, hour=0)  code = 410
# Error on request 4346 (station=8012170, hour=1)  code = 410
# Error on request 4347 (station=8012170, hour=2)  code = 410
# Error on request 4348 (station=8012170, hour=3)  code = 410
# 4360 timetables (of 9600 ) so far. Taking a break.
# Error on request 4369 (station=8012174, hour=0)  code = 410
# Error on request 4370 (station=8012174, hour=1)  code = 410
# Error on request 4371 (station=8012174, hour=2)  code = 410
# Error on request 4372 (station=8012174, hour=3)  code = 410
# 4380 timetables (of 9600 ) so far. Taking a break.
# Error on request 4393 (station=8012175, hour=0)  code = 410
# Error on request 4394 (station=8012175, hour=1)  code = 410
# Error on request 4395 (station=8012175, hour=2)  code = 410
# Error on request 4396 (station=8012175, hour=3)  code = 410
# 4400 timetables (of 9600 ) so far. Taking a break.
# Error on request 4417 (station=8012178, hour=0)  code = 410
# Error on request 4418 (station=8012178, hour=1)  code = 410
# Error on request 4419 (station=8012178, hour=2)  code = 410
# Error on request 4420 (station=8012178, hour=3)  code = 410
# 4420 timetables (of 9600 ) so far. Taking a break.
# 4440 timetables (of 9600 ) so far. Taking a break.
# Error on request 4441 (station=8010205, hour=0)  code = 410
# Error on request 4442 (station=8010205, hour=1)  code = 410
# Error on request 4443 (station=8010205, hour=2)  code = 410
# Error on request 4444 (station=8010205, hour=3)  code = 410
# 4460 timetables (of 9600 ) so far. Taking a break.
# Error on request 4465 (station=8012343, hour=0)  code = 410
# Error on request 4466 (station=8012343, hour=1)  code = 410
# Error on request 4467 (station=8012343, hour=2)  code = 410
# Error on request 4468 (station=8012343, hour=3)  code = 410
# 4480 timetables (of 9600 ) so far. Taking a break.
# Error on request 4489 (station=8010206, hour=0)  code = 410
# Error on request 4490 (station=8010206, hour=1)  code = 410
# Error on request 4491 (station=8010206, hour=2)  code = 410
# Error on request 4492 (station=8010206, hour=3)  code = 410
# 4500 timetables (of 9600 ) so far. Taking a break.
# Error on request 4513 (station=8012188, hour=0)  code = 410
# Error on request 4514 (station=8012188, hour=1)  code = 410
# Error on request 4515 (station=8012188, hour=2)  code = 410
# Error on request 4516 (station=8012188, hour=3)  code = 410
# 4520 timetables (of 9600 ) so far. Taking a break.
# Error on request 4537 (station=8012190, hour=0)  code = 410
# Error on request 4538 (station=8012190, hour=1)  code = 410
# Error on request 4539 (station=8012190, hour=2)  code = 410
# Error on request 4540 (station=8012190, hour=3)  code = 410
# 4540 timetables (of 9600 ) so far. Taking a break.
# 4560 timetables (of 9600 ) so far. Taking a break.
# Error on request 4561 (station=8012192, hour=0)  code = 410
# Error on request 4562 (station=8012192, hour=1)  code = 410
# Error on request 4563 (station=8012192, hour=2)  code = 410
# Error on request 4564 (station=8012192, hour=3)  code = 410
# 4580 timetables (of 9600 ) so far. Taking a break.
# Error on request 4585 (station=8010207, hour=0)  code = 410
# Error on request 4586 (station=8010207, hour=1)  code = 410
# Error on request 4587 (station=8010207, hour=2)  code = 410
# Error on request 4588 (station=8010207, hour=3)  code = 410
# 4600 timetables (of 9600 ) so far. Taking a break.
# Error on request 4609 (station=8012193, hour=0)  code = 410
# Error on request 4610 (station=8012193, hour=1)  code = 410
# Error on request 4611 (station=8012193, hour=2)  code = 410
# Error on request 4612 (station=8012193, hour=3)  code = 410
# 4620 timetables (of 9600 ) so far. Taking a break.
# Error on request 4633 (station=8010208, hour=0)  code = 410
# Error on request 4634 (station=8010208, hour=1)  code = 410
# Error on request 4635 (station=8010208, hour=2)  code = 410
# Error on request 4636 (station=8010208, hour=3)  code = 410
# 4640 timetables (of 9600 ) so far. Taking a break.
# Error on request 4657 (station=8010209, hour=0)  code = 410
# Error on request 4658 (station=8010209, hour=1)  code = 410
# Error on request 4659 (station=8010209, hour=2)  code = 410
# Error on request 4660 (station=8010209, hour=3)  code = 410
# 4660 timetables (of 9600 ) so far. Taking a break.
# 4680 timetables (of 9600 ) so far. Taking a break.
# Error on request 4681 (station=8012194, hour=0)  code = 410
# Error on request 4682 (station=8012194, hour=1)  code = 410
# Error on request 4683 (station=8012194, hour=2)  code = 410
# Error on request 4684 (station=8012194, hour=3)  code = 410
# 4700 timetables (of 9600 ) so far. Taking a break.
# Error on request 4705 (station=8012195, hour=0)  code = 410
# Error on request 4706 (station=8012195, hour=1)  code = 410
# Error on request 4707 (station=8012195, hour=2)  code = 410
# Error on request 4708 (station=8012195, hour=3)  code = 410
# 4720 timetables (of 9600 ) so far. Taking a break.
# Error on request 4729 (station=8012197, hour=0)  code = 410
# Error on request 4730 (station=8012197, hour=1)  code = 410
# Error on request 4731 (station=8012197, hour=2)  code = 410
# Error on request 4732 (station=8012197, hour=3)  code = 410
# 4740 timetables (of 9600 ) so far. Taking a break.
# Error on request 4753 (station=8012198, hour=0)  code = 410
# Error on request 4754 (station=8012198, hour=1)  code = 410
# Error on request 4755 (station=8012198, hour=2)  code = 410
# Error on request 4756 (station=8012198, hour=3)  code = 410
# 4760 timetables (of 9600 ) so far. Taking a break.
# Error on request 4777 (station=8012203, hour=0)  code = 410
# Error on request 4778 (station=8012203, hour=1)  code = 410
# Error on request 4779 (station=8012203, hour=2)  code = 410
# Error on request 4780 (station=8012203, hour=3)  code = 410
# 4780 timetables (of 9600 ) so far. Taking a break.
# 4800 timetables (of 9600 ) so far. Taking a break.
# Error on request 4801 (station=8012220, hour=0)  code = 410
# Error on request 4802 (station=8012220, hour=1)  code = 410
# Error on request 4803 (station=8012220, hour=2)  code = 410
# Error on request 4804 (station=8012220, hour=3)  code = 410
# 4820 timetables (of 9600 ) so far. Taking a break.
# Error on request 4825 (station=8012223, hour=0)  code = 410
# Error on request 4826 (station=8012223, hour=1)  code = 410
# Error on request 4827 (station=8012223, hour=2)  code = 410
# Error on request 4828 (station=8012223, hour=3)  code = 410
# 4840 timetables (of 9600 ) so far. Taking a break.
# Error on request 4849 (station=8012224, hour=0)  code = 410
# Error on request 4850 (station=8012224, hour=1)  code = 410
# Error on request 4851 (station=8012224, hour=2)  code = 410
# Error on request 4852 (station=8012224, hour=3)  code = 410
# 4860 timetables (of 9600 ) so far. Taking a break.
# Error on request 4873 (station=8012228, hour=0)  code = 410
# Error on request 4874 (station=8012228, hour=1)  code = 410
# Error on request 4875 (station=8012228, hour=2)  code = 410
# Error on request 4876 (station=8012228, hour=3)  code = 410
# 4880 timetables (of 9600 ) so far. Taking a break.
# Error on request 4897 (station=8012231, hour=0)  code = 410
# Error on request 4898 (station=8012231, hour=1)  code = 410
# Error on request 4899 (station=8012231, hour=2)  code = 410
# Error on request 4900 (station=8012231, hour=3)  code = 410
# 4900 timetables (of 9600 ) so far. Taking a break.
# 4920 timetables (of 9600 ) so far. Taking a break.
# Error on request 4921 (station=8012232, hour=0)  code = 410
# Error on request 4922 (station=8012232, hour=1)  code = 410
# Error on request 4923 (station=8012232, hour=2)  code = 410
# Error on request 4924 (station=8012232, hour=3)  code = 410
# 4940 timetables (of 9600 ) so far. Taking a break.
# Error on request 4945 (station=8012236, hour=0)  code = 410
# Error on request 4946 (station=8012236, hour=1)  code = 410
# Error on request 4947 (station=8012236, hour=2)  code = 410
# Error on request 4948 (station=8012236, hour=3)  code = 410
# Error on request 4949 (station=8012236, hour=4)  code = 410
# 4960 timetables (of 9600 ) so far. Taking a break.
# Error on request 4969 (station=8010212, hour=0)  code = 410
# Error on request 4970 (station=8010212, hour=1)  code = 410
# Error on request 4971 (station=8010212, hour=2)  code = 410
# Error on request 4972 (station=8010212, hour=3)  code = 410
# Error on request 4973 (station=8010212, hour=4)  code = 410
# 4980 timetables (of 9600 ) so far. Taking a break.
# Error on request 4993 (station=8012241, hour=0)  code = 410
# Error on request 4994 (station=8012241, hour=1)  code = 410
# Error on request 4995 (station=8012241, hour=2)  code = 410
# Error on request 4996 (station=8012241, hour=3)  code = 410
# Error on request 4997 (station=8012241, hour=4)  code = 410
# 5000 timetables (of 9600 ) so far. Taking a break.
# Error on request 5017 (station=8012249, hour=0)  code = 410
# Error on request 5018 (station=8012249, hour=1)  code = 410
# Error on request 5019 (station=8012249, hour=2)  code = 410
# Error on request 5020 (station=8012249, hour=3)  code = 410
# 5020 timetables (of 9600 ) so far. Taking a break.
# Error on request 5021 (station=8012249, hour=4)  code = 410
# 5040 timetables (of 9600 ) so far. Taking a break.
# Error on request 5041 (station=8012250, hour=0)  code = 410
# Error on request 5042 (station=8012250, hour=1)  code = 410
# Error on request 5043 (station=8012250, hour=2)  code = 410
# Error on request 5044 (station=8012250, hour=3)  code = 410
# Error on request 5045 (station=8012250, hour=4)  code = 410
# 5060 timetables (of 9600 ) so far. Taking a break.
# Error on request 5065 (station=8012285, hour=0)  code = 410
# Error on request 5066 (station=8012285, hour=1)  code = 410
# Error on request 5067 (station=8012285, hour=2)  code = 410
# Error on request 5068 (station=8012285, hour=3)  code = 410
# Error on request 5069 (station=8012285, hour=4)  code = 410
# 5080 timetables (of 9600 ) so far. Taking a break.
# Error on request 5089 (station=8012284, hour=0)  code = 410
# Error on request 5090 (station=8012284, hour=1)  code = 410
# Error on request 5091 (station=8012284, hour=2)  code = 410
# Error on request 5092 (station=8012284, hour=3)  code = 410
# Error on request 5093 (station=8012284, hour=4)  code = 410
# 5100 timetables (of 9600 ) so far. Taking a break.
# Error on request 5113 (station=8012308, hour=0)  code = 410
# Error on request 5114 (station=8012308, hour=1)  code = 410
# Error on request 5115 (station=8012308, hour=2)  code = 410
# Error on request 5116 (station=8012308, hour=3)  code = 410
# Error on request 5117 (station=8012308, hour=4)  code = 410
# 5120 timetables (of 9600 ) so far. Taking a break.
# Error on request 5137 (station=8012309, hour=0)  code = 410
# Error on request 5138 (station=8012309, hour=1)  code = 410
# Error on request 5139 (station=8012309, hour=2)  code = 410
# Error on request 5140 (station=8012309, hour=3)  code = 410
# 5140 timetables (of 9600 ) so far. Taking a break.
# Error on request 5141 (station=8012309, hour=4)  code = 410
# 5160 timetables (of 9600 ) so far. Taking a break.
# Error on request 5161 (station=8010228, hour=0)  code = 410
# Error on request 5162 (station=8010228, hour=1)  code = 410
# Error on request 5163 (station=8010228, hour=2)  code = 410
# Error on request 5164 (station=8010228, hour=3)  code = 410
# Error on request 5165 (station=8010228, hour=4)  code = 410
# 5180 timetables (of 9600 ) so far. Taking a break.
# Error on request 5185 (station=8012311, hour=0)  code = 410
# Error on request 5186 (station=8012311, hour=1)  code = 410
# Error on request 5187 (station=8012311, hour=2)  code = 410
# Error on request 5188 (station=8012311, hour=3)  code = 410
# Error on request 5189 (station=8012311, hour=4)  code = 410
# 5200 timetables (of 9600 ) so far. Taking a break.
# Error on request 5209 (station=8012323, hour=0)  code = 410
# Error on request 5210 (station=8012323, hour=1)  code = 410
# Error on request 5211 (station=8012323, hour=2)  code = 410
# Error on request 5212 (station=8012323, hour=3)  code = 410
# Error on request 5213 (station=8012323, hour=4)  code = 410
# 5220 timetables (of 9600 ) so far. Taking a break.
# Error on request 5233 (station=8010229, hour=0)  code = 410
# Error on request 5234 (station=8010229, hour=1)  code = 410
# Error on request 5235 (station=8010229, hour=2)  code = 410
# Error on request 5236 (station=8010229, hour=3)  code = 410
# Error on request 5237 (station=8010229, hour=4)  code = 410
# 5240 timetables (of 9600 ) so far. Taking a break.
# Error on request 5257 (station=8012326, hour=0)  code = 410
# Error on request 5258 (station=8012326, hour=1)  code = 410
# Error on request 5259 (station=8012326, hour=2)  code = 410
# Error on request 5260 (station=8012326, hour=3)  code = 410
# 5260 timetables (of 9600 ) so far. Taking a break.
# ...
# 8920 timetables (of 9600 ) so far. Taking a break.
# Error on request 8929 (station=8013436, hour=0)  code = 410
# Error on request 8930 (station=8013436, hour=1)  code = 410
# Error on request 8931 (station=8013436, hour=2)  code = 410
# Error on request 8932 (station=8013436, hour=3)  code = 410
# Error on request 8933 (station=8013436, hour=4)  code = 410
# Error on request 8934 (station=8013436, hour=5)  code = 410
# Error on request 8935 (station=8013436, hour=6)  code = 410
# Error on request 8936 (station=8013436, hour=7)  code = 410
# 8940 timetables (of 9600 ) so far. Taking a break.
# Error on request 8953 (station=8010398, hour=0)  code = 410
# Error on request 8954 (station=8010398, hour=1)  code = 410
# Error on request 8955 (station=8010398, hour=2)  code = 410
# Error on request 8956 (station=8010398, hour=3)  code = 410
# Error on request 8957 (station=8010398, hour=4)  code = 410
# Error on request 8958 (station=8010398, hour=5)  code = 410
# Error on request 8959 (station=8010398, hour=6)  code = 410
# Error on request 8960 (station=8010398, hour=7)  code = 410
# 8960 timetables (of 9600 ) so far. Taking a break.
# Error on request 8977 (station=8012478, hour=0)  code = 410
# Error on request 8978 (station=8012478, hour=1)  code = 410
# Error on request 8979 (station=8012478, hour=2)  code = 410
# Error on request 8980 (station=8012478, hour=3)  code = 410
# 8980 timetables (of 9600 ) so far. Taking a break.
# Error on request 8981 (station=8012478, hour=4)  code = 410
# Error on request 8982 (station=8012478, hour=5)  code = 410
# Error on request 8983 (station=8012478, hour=6)  code = 410
# Error on request 8984 (station=8012478, hour=7)  code = 410
# 9000 timetables (of 9600 ) so far. Taking a break.
# Error on request 9001 (station=8012183, hour=0)  code = 410
# Error on request 9002 (station=8012183, hour=1)  code = 410
# Error on request 9003 (station=8012183, hour=2)  code = 410
# Error on request 9004 (station=8012183, hour=3)  code = 410
# Error on request 9005 (station=8012183, hour=4)  code = 410
# Error on request 9006 (station=8012183, hour=5)  code = 410
# Error on request 9007 (station=8012183, hour=6)  code = 410
# Error on request 9008 (station=8012183, hour=7)  code = 410
# 9020 timetables (of 9600 ) so far. Taking a break.
# Error on request 9025 (station=8011399, hour=0)  code = 410
# Error on request 9026 (station=8011399, hour=1)  code = 410
# Error on request 9027 (station=8011399, hour=2)  code = 410
# Error on request 9028 (station=8011399, hour=3)  code = 410
# Error on request 9029 (station=8011399, hour=4)  code = 410
# Error on request 9030 (station=8011399, hour=5)  code = 410
# Error on request 9031 (station=8011399, hour=6)  code = 410
# Error on request 9032 (station=8011399, hour=7)  code = 410
# 9040 timetables (of 9600 ) so far. Taking a break.
# Error on request 9049 (station=8000343, hour=0)  code = 410
# Error on request 9050 (station=8000343, hour=1)  code = 410
# Error on request 9051 (station=8000343, hour=2)  code = 410
# Error on request 9052 (station=8000343, hour=3)  code = 410
# Error on request 9053 (station=8000343, hour=4)  code = 410
# Error on request 9054 (station=8000343, hour=5)  code = 410
# Error on request 9055 (station=8000343, hour=6)  code = 410
# Error on request 9056 (station=8000343, hour=7)  code = 410
# 9060 timetables (of 9600 ) so far. Taking a break.
# Error on request 9073 (station=8011491, hour=0)  code = 410
# Error on request 9074 (station=8011491, hour=1)  code = 410
# Error on request 9075 (station=8011491, hour=2)  code = 410
# Error on request 9076 (station=8011491, hour=3)  code = 410
# Error on request 9077 (station=8011491, hour=4)  code = 410
# Error on request 9078 (station=8011491, hour=5)  code = 410
# Error on request 9079 (station=8011491, hour=6)  code = 410
# Error on request 9080 (station=8011491, hour=7)  code = 410
# 9080 timetables (of 9600 ) so far. Taking a break.
# Error on request 9097 (station=8012869, hour=0)  code = 410
# Error on request 9098 (station=8012869, hour=1)  code = 410
# Error on request 9099 (station=8012869, hour=2)  code = 410
# Error on request 9100 (station=8012869, hour=3)  code = 410
# 9100 timetables (of 9600 ) so far. Taking a break.
# Error on request 9101 (station=8012869, hour=4)  code = 410
# Error on request 9102 (station=8012869, hour=5)  code = 410
# Error on request 9103 (station=8012869, hour=6)  code = 410
# Error on request 9104 (station=8012869, hour=7)  code = 410
# 9120 timetables (of 9600 ) so far. Taking a break.
# Error on request 9121 (station=8012641, hour=0)  code = 410
# Error on request 9122 (station=8012641, hour=1)  code = 410
# Error on request 9123 (station=8012641, hour=2)  code = 410
# Error on request 9124 (station=8012641, hour=3)  code = 410
# Error on request 9125 (station=8012641, hour=4)  code = 410
# Error on request 9126 (station=8012641, hour=5)  code = 410
# Error on request 9127 (station=8012641, hour=6)  code = 410
# Error on request 9128 (station=8012641, hour=7)  code = 410
# 9140 timetables (of 9600 ) so far. Taking a break.
# Error on request 9145 (station=8011431, hour=0)  code = 410
# Error on request 9146 (station=8011431, hour=1)  code = 410
# Error on request 9147 (station=8011431, hour=2)  code = 410
# Error on request 9148 (station=8011431, hour=3)  code = 410
# Error on request 9149 (station=8011431, hour=4)  code = 410
# Error on request 9150 (station=8011431, hour=5)  code = 410
# Error on request 9151 (station=8011431, hour=6)  code = 410
# Error on request 9152 (station=8011431, hour=7)  code = 410
# 9160 timetables (of 9600 ) so far. Taking a break.
# Error on request 9169 (station=8011416, hour=0)  code = 410
# Error on request 9170 (station=8011416, hour=1)  code = 410
# Error on request 9171 (station=8011416, hour=2)  code = 410
# Error on request 9172 (station=8011416, hour=3)  code = 410
# Error on request 9173 (station=8011416, hour=4)  code = 410
# Error on request 9174 (station=8011416, hour=5)  code = 410
# Error on request 9175 (station=8011416, hour=6)  code = 410
# Error on request 9176 (station=8011416, hour=7)  code = 410
# 9180 timetables (of 9600 ) so far. Taking a break.
# Error on request 9193 (station=8012181, hour=0)  code = 410
# Error on request 9194 (station=8012181, hour=1)  code = 410
# Error on request 9195 (station=8012181, hour=2)  code = 410
# Error on request 9196 (station=8012181, hour=3)  code = 410
# Error on request 9197 (station=8012181, hour=4)  code = 410
# Error on request 9198 (station=8012181, hour=5)  code = 410
# Error on request 9199 (station=8012181, hour=6)  code = 410
# Error on request 9200 (station=8012181, hour=7)  code = 410
# 9200 timetables (of 9600 ) so far. Taking a break.
# Error on request 9217 (station=8012863, hour=0)  code = 410
# Error on request 9218 (station=8012863, hour=1)  code = 410
# Error on request 9219 (station=8012863, hour=2)  code = 410
# Error on request 9220 (station=8012863, hour=3)  code = 410
# 9220 timetables (of 9600 ) so far. Taking a break.
# Error on request 9221 (station=8012863, hour=4)  code = 410
# Error on request 9222 (station=8012863, hour=5)  code = 410
# Error on request 9223 (station=8012863, hour=6)  code = 410
# Error on request 9224 (station=8012863, hour=7)  code = 410
# 9240 timetables (of 9600 ) so far. Taking a break.
# Error on request 9241 (station=8012204, hour=0)  code = 410
# Error on request 9242 (station=8012204, hour=1)  code = 410
# Error on request 9243 (station=8012204, hour=2)  code = 410
# Error on request 9244 (station=8012204, hour=3)  code = 410
# Error on request 9245 (station=8012204, hour=4)  code = 410
# Error on request 9246 (station=8012204, hour=5)  code = 410
# Error on request 9247 (station=8012204, hour=6)  code = 410
# Error on request 9248 (station=8012204, hour=7)  code = 410
# 9260 timetables (of 9600 ) so far. Taking a break.
# Error on request 9265 (station=8012186, hour=0)  code = 410
# Error on request 9266 (station=8012186, hour=1)  code = 410
# Error on request 9267 (station=8012186, hour=2)  code = 410
# Error on request 9268 (station=8012186, hour=3)  code = 410
# Error on request 9269 (station=8012186, hour=4)  code = 410
# Error on request 9270 (station=8012186, hour=5)  code = 410
# Error on request 9271 (station=8012186, hour=6)  code = 410
# Error on request 9272 (station=8012186, hour=7)  code = 410
# 9280 timetables (of 9600 ) so far. Taking a break.
# Error on request 9289 (station=8012202, hour=0)  code = 410
# Error on request 9290 (station=8012202, hour=1)  code = 410
# Error on request 9291 (station=8012202, hour=2)  code = 410
# Error on request 9292 (station=8012202, hour=3)  code = 410
# Error on request 9293 (station=8012202, hour=4)  code = 410
# Error on request 9294 (station=8012202, hour=5)  code = 410
# Error on request 9295 (station=8012202, hour=6)  code = 410
# Error on request 9296 (station=8012202, hour=7)  code = 410
# 9300 timetables (of 9600 ) so far. Taking a break.
# Error on request 9313 (station=8012184, hour=0)  code = 410
# Error on request 9314 (station=8012184, hour=1)  code = 410
# Error on request 9315 (station=8012184, hour=2)  code = 410
# Error on request 9316 (station=8012184, hour=3)  code = 410
# Error on request 9317 (station=8012184, hour=4)  code = 410
# Error on request 9318 (station=8012184, hour=5)  code = 410
# Error on request 9319 (station=8012184, hour=6)  code = 410
# Error on request 9320 (station=8012184, hour=7)  code = 410
# 9320 timetables (of 9600 ) so far. Taking a break.
# Error on request 9321 (station=8012184, hour=8)  code = 410
# Error on request 9337 (station=8012187, hour=0)  code = 410
# Error on request 9338 (station=8012187, hour=1)  code = 410
# Error on request 9339 (station=8012187, hour=2)  code = 410
# Error on request 9340 (station=8012187, hour=3)  code = 410
# 9340 timetables (of 9600 ) so far. Taking a break.
# Error on request 9341 (station=8012187, hour=4)  code = 410
# Error on request 9342 (station=8012187, hour=5)  code = 410
# Error on request 9343 (station=8012187, hour=6)  code = 410
# Error on request 9344 (station=8012187, hour=7)  code = 410
# Error on request 9345 (station=8012187, hour=8)  code = 410
# 9360 timetables (of 9600 ) so far. Taking a break.
# Error on request 9361 (station=8010336, hour=0)  code = 410
# Error on request 9362 (station=8010336, hour=1)  code = 410
# Error on request 9363 (station=8010336, hour=2)  code = 410
# Error on request 9364 (station=8010336, hour=3)  code = 410
# Error on request 9365 (station=8010336, hour=4)  code = 410
# Error on request 9366 (station=8010336, hour=5)  code = 410
# Error on request 9367 (station=8010336, hour=6)  code = 410
# Error on request 9368 (station=8010336, hour=7)  code = 410
# Error on request 9369 (station=8010336, hour=8)  code = 410
# 9380 timetables (of 9600 ) so far. Taking a break.
# Error on request 9385 (station=8013267, hour=0)  code = 410
# Error on request 9386 (station=8013267, hour=1)  code = 410
# Error on request 9387 (station=8013267, hour=2)  code = 410
# Error on request 9388 (station=8013267, hour=3)  code = 410
# Error on request 9389 (station=8013267, hour=4)  code = 410
# Error on request 9390 (station=8013267, hour=5)  code = 410
# Error on request 9391 (station=8013267, hour=6)  code = 410
# Error on request 9392 (station=8013267, hour=7)  code = 410
# Error on request 9393 (station=8013267, hour=8)  code = 410
# 9400 timetables (of 9600 ) so far. Taking a break.
# Error on request 9409 (station=8012196, hour=0)  code = 410
# Error on request 9410 (station=8012196, hour=1)  code = 410
# Error on request 9411 (station=8012196, hour=2)  code = 410
# Error on request 9412 (station=8012196, hour=3)  code = 410
# Error on request 9413 (station=8012196, hour=4)  code = 410
# Error on request 9414 (station=8012196, hour=5)  code = 410
# Error on request 9415 (station=8012196, hour=6)  code = 410
# Error on request 9416 (station=8012196, hour=7)  code = 410
# Error on request 9417 (station=8012196, hour=8)  code = 410
# 9420 timetables (of 9600 ) so far. Taking a break.
# Error on request 9433 (station=8012273, hour=0)  code = 410
# Error on request 9434 (station=8012273, hour=1)  code = 410
# Error on request 9435 (station=8012273, hour=2)  code = 410
# Error on request 9436 (station=8012273, hour=3)  code = 410
# Error on request 9437 (station=8012273, hour=4)  code = 410
# Error on request 9438 (station=8012273, hour=5)  code = 410
# Error on request 9439 (station=8012273, hour=6)  code = 410
# Error on request 9440 (station=8012273, hour=7)  code = 410
# 9440 timetables (of 9600 ) so far. Taking a break.
# Error on request 9441 (station=8012273, hour=8)  code = 410
# Error on request 9457 (station=8012318, hour=0)  code = 410
# Error on request 9458 (station=8012318, hour=1)  code = 410
# Error on request 9459 (station=8012318, hour=2)  code = 410
# Error on request 9460 (station=8012318, hour=3)  code = 410
# 9460 timetables (of 9600 ) so far. Taking a break.
# Error on request 9461 (station=8012318, hour=4)  code = 410
# Error on request 9462 (station=8012318, hour=5)  code = 410
# Error on request 9463 (station=8012318, hour=6)  code = 410
# Error on request 9464 (station=8012318, hour=7)  code = 410
# Error on request 9465 (station=8012318, hour=8)  code = 410
# 9480 timetables (of 9600 ) so far. Taking a break.
# Error on request 9481 (station=8017442, hour=0)  code = 410
# Error on request 9482 (station=8017442, hour=1)  code = 410
# Error on request 9483 (station=8017442, hour=2)  code = 410
# Error on request 9484 (station=8017442, hour=3)  code = 410
# Error on request 9485 (station=8017442, hour=4)  code = 410
# Error on request 9486 (station=8017442, hour=5)  code = 410
# Error on request 9487 (station=8017442, hour=6)  code = 410
# Error on request 9488 (station=8017442, hour=7)  code = 410
# Error on request 9489 (station=8017442, hour=8)  code = 410
# 9500 timetables (of 9600 ) so far. Taking a break.
# Error on request 9505 (station=8012686, hour=0)  code = 410
# Error on request 9506 (station=8012686, hour=1)  code = 410
# Error on request 9507 (station=8012686, hour=2)  code = 410
# Error on request 9508 (station=8012686, hour=3)  code = 410
# Error on request 9509 (station=8012686, hour=4)  code = 410
# Error on request 9510 (station=8012686, hour=5)  code = 410
# Error on request 9511 (station=8012686, hour=6)  code = 410
# Error on request 9512 (station=8012686, hour=7)  code = 410
# Error on request 9513 (station=8012686, hour=8)  code = 410
# 9520 timetables (of 9600 ) so far. Taking a break.
# Error on request 9529 (station=8012304, hour=0)  code = 410
# Error on request 9530 (station=8012304, hour=1)  code = 410
# Error on request 9531 (station=8012304, hour=2)  code = 410
# Error on request 9532 (station=8012304, hour=3)  code = 410
# Error on request 9533 (station=8012304, hour=4)  code = 410
# Error on request 9534 (station=8012304, hour=5)  code = 410
# Error on request 9535 (station=8012304, hour=6)  code = 410
# Error on request 9536 (station=8012304, hour=7)  code = 410
# Error on request 9537 (station=8012304, hour=8)  code = 410
# 9540 timetables (of 9600 ) so far. Taking a break.
# Error on request 9553 (station=8017050, hour=0)  code = 410
# Error on request 9554 (station=8017050, hour=1)  code = 410
# Error on request 9555 (station=8017050, hour=2)  code = 410
# Error on request 9556 (station=8017050, hour=3)  code = 410
# Error on request 9557 (station=8017050, hour=4)  code = 410
# Error on request 9558 (station=8017050, hour=5)  code = 410
# Error on request 9559 (station=8017050, hour=6)  code = 410
# Error on request 9560 (station=8017050, hour=7)  code = 410
# 9560 timetables (of 9600 ) so far. Taking a break.
# Error on request 9561 (station=8017050, hour=8)  code = 410
# Error on request 9577 (station=8012200, hour=0)  code = 410
# Error on request 9578 (station=8012200, hour=1)  code = 410
# Error on request 9579 (station=8012200, hour=2)  code = 410
# Error on request 9580 (station=8012200, hour=3)  code = 410
# 9580 timetables (of 9600 ) so far. Taking a break.
# Error on request 9581 (station=8012200, hour=4)  code = 410
# Error on request 9582 (station=8012200, hour=5)  code = 410
# Error on request 9583 (station=8012200, hour=6)  code = 410
# Error on request 9584 (station=8012200, hour=7)  code = 410
# Error on request 9585 (station=8012200, hour=8)  code = 410
# 9600 timetables (of 9600 ) so far. Taking a break.

# %%
len(error_combinations)
# Out:
# 1844

# %%
import json

# %%
with open("timetables/errors.json", "w") as error_file:
    json.dump(error_combinations, error_file)

# %%
errors = None
with open("timetables/errors.json", "r") as error_file:
    errors = json.load(error_file)
errors
# Out:
# [[8011132, 0],
#  [8010044, 0],
#  [8010046, 0],
#  [8011185, 0],
#  [8011199, 0],
#  [8010049, 0],
#  [8013471, 0],
#  [8011222, 0],
#  [8011242, 0],
#  [8010059, 0],
#  [8011257, 0],
#  [8011264, 0],
#  [8011297, 0],
#  [8011298, 0],
#  [8010184, 0],
#  [8011970, 0],
#  [8011971, 0],
#  [8010185, 0],
#  [8011974, 0],
#  [8013450, 0],
#  [8011979, 0],
#  [8011980, 0],
#  [8011315, 0],
#  [8080840, 0],
#  [8011320, 0],
#  [8010072, 0],
#  [8010074, 0],
#  [8011325, 0],
#  [8011339, 0],
#  [8080280, 0],
#  [8010076, 0],
#  [8011354, 0],
#  [8011371, 0],
#  [8011385, 0],
#  [8010080, 0],
#  [8011387, 0],
#  [8011398, 0],
#  [8011407, 0],
#  [8011407, 1],
#  [8011407, 2],
#  [8011407, 3],
#  [8011407, 4],
#  [8011407, 5],
#  [8011407, 6],
#  [8011407, 7],
#  [8011407, 8],
#  [8011407, 9],
#  [8011407, 10],
#  [8011407, 11],
#  [8011407, 12],
#  [8011407, 13],
#  [8011407, 14],
#  [8011407, 15],
#  [8011407, 16],
#  [8011407, 17],
#  [8011407, 18],
#  [8011407, 19],
#  [8011407, 20],
#  [8011407, 21],
#  [8011407, 22],
#  [8011407, 23],
#  [8011417, 0],
#  [8010085, 0],
#  [8011418, 0],
#  [8013444, 0],
#  [8011419, 0],
#  [8011420, 0],
#  [8013475, 0],
#  [8011421, 0],
#  [8010088, 0],
#  [8010089, 0],
#  [8010089, 1],
#  [8011422, 0],
#  [8011422, 1],
#  [8011423, 0],
#  [8011423, 1],
#  [8013476, 0],
#  [8013476, 1],
#  [8011424, 0],
#  [8011424, 1],
#  [8011425, 0],
#  [8011425, 1],
#  [8011426, 0],
#  [8011426, 1],
#  [8011427, 0],
#  [8011427, 1],
#  [8011428, 0],
#  [8011428, 1],
#  [8010091, 0],
#  [8010091, 1],
#  [8010092, 0],
#  [8010092, 1],
#  [8011446, 0],
#  [8011446, 1],
#  [8011451, 0],
#  [8011451, 1],
#  [8010094, 0],
#  [8010094, 1],
#  [8010095, 0],
#  [8010095, 1],
#  [8010161, 0],
#  [8010161, 1],
#  [8011477, 0],
#  [8011477, 1],
#  [8011487, 0],
#  [8011487, 1],
#  [8011488, 0],
#  [8011488, 1],
#  [8011495, 0],
#  [8011495, 1],
#  [8011507, 0],
#  [8011507, 1],
#  [8011529, 0],
#  [8011529, 1],
#  [8010106, 0],
#  [8010106, 1],
#  [8010108, 0],
#  [8010108, 1],
#  [8011553, 0],
#  [8011553, 1],
#  [8011554, 0],
#  [8011554, 1],
#  [8011556, 0],
#  [8011556, 1],
#  [8011563, 0],
#  [8011563, 1],
#  [8010115, 0],
#  [8010115, 1],
#  [8011569, 0],
#  [8011569, 1],
#  [8010116, 0],
#  [8010116, 1],
#  [8011570, 0],
#  [8011570, 1],
#  [8013445, 0],
#  [8013445, 1],
#  [8011588, 0],
#  [8011588, 1],
#  [8011598, 0],
#  [8011598, 1],
#  [8011609, 0],
#  [8011609, 1],
#  [8010122, 0],
#  [8010122, 1],
#  [8011626, 0],
#  [8011626, 1],
#  [8011628, 0],
#  [8011628, 1],
#  [8011636, 0],
#  [8011636, 1],
#  [8011637, 0],
#  [8011637, 1],
#  [8010129, 0],
#  [8010129, 1],
#  [8010130, 0],
#  [8010130, 1],
#  [8010131, 0],
#  [8010131, 1],
#  [8011656, 0],
#  [8011656, 1],
#  [8011676, 0],
#  [8011676, 1],
#  [8011705, 0],
#  [8011705, 1],
#  [8011709, 0],
#  [8011709, 1],
#  [8011712, 0],
#  [8011712, 1],
#  [8011712, 2],
#  [8013447, 0],
#  [8013447, 1],
#  [8013447, 2],
#  [8010144, 0],
#  [8010144, 1],
#  [8010144, 2],
#  [8011745, 0],
#  [8011745, 1],
#  [8011745, 2],
#  [8011749, 0],
#  [8011749, 1],
#  [8011749, 2],
#  [8011751, 0],
#  [8011751, 1],
#  [8011751, 2],
#  [8011753, 0],
#  [8011753, 1],
#  [8011753, 2],
#  [8011755, 0],
#  [8011755, 1],
#  [8011755, 2],
#  [8011758, 0],
#  [8011758, 1],
#  [8011758, 2],
#  [8011761, 0],
#  [8011761, 1],
#  [8011761, 2],
#  [8011763, 0],
#  [8011763, 1],
#  [8011763, 2],
#  [8011770, 0],
#  [8011770, 1],
#  [8011770, 2],
#  [8011771, 0],
#  [8011771, 1],
#  [8011771, 2],
#  [8011773, 0],
#  [8011773, 1],
#  [8011773, 2],
#  [8011790, 0],
#  [8011790, 1],
#  [8011790, 2],
#  [8011799, 0],
#  [8011799, 1],
#  [8011799, 2],
#  [8011795, 0],
#  [8011795, 1],
#  [8011795, 2],
#  [8011801, 0],
#  [8011801, 1],
#  [8011801, 2],
#  [8011802, 0],
#  [8011802, 1],
#  [8011802, 2],
#  [8011825, 0],
#  [8011825, 1],
#  [8011825, 2],
#  [8010163, 0],
#  [8010163, 1],
#  [8010163, 2],
#  [8011843, 0],
#  [8011843, 1],
#  [8011843, 2],
#  [8011844, 0],
#  [8011844, 1],
#  [8011844, 2],
#  [8011855, 0],
#  [8011855, 1],
#  [8011855, 2],
#  [8010166, 0],
#  [8010166, 1],
#  [8010166, 2],
#  [8011861, 0],
#  [8011861, 1],
#  [8011861, 2],
#  [8011878, 0],
#  [8011878, 1],
#  [8011878, 2],
#  [8011900, 0],
#  [8011900, 1],
#  [8011900, 2],
#  [8011904, 0],
#  [8011904, 1],
#  [8011904, 2],
#  [8011912, 0],
#  [8011912, 1],
#  [8011912, 2],
#  [8011913, 0],
#  [8011913, 1],
#  [8011913, 2],
#  [8011914, 0],
#  [8011914, 1],
#  [8011914, 2],
#  [8010174, 0],
#  [8010174, 1],
#  [8010174, 2],
#  [8010177, 0],
#  [8010177, 1],
#  [8010177, 2],
#  [8011922, 0],
#  [8011922, 1],
#  [8011922, 2],
#  [8011928, 0],
#  [8011928, 1],
#  [8011928, 2],
#  [8011937, 0],
#  [8011937, 1],
#  [8011937, 2],
#  [8011959, 0],
#  [8011959, 1],
#  [8011959, 2],
#  [8011963, 0],
#  [8011963, 1],
#  [8011963, 2],
#  [8011966, 0],
#  [8011966, 1],
#  [8011966, 2],
#  [8011988, 0],
#  [8011988, 1],
#  [8011988, 2],
#  [8011983, 0],
#  [8011983, 1],
#  [8011983, 2],
#  [8010186, 0],
#  [8010186, 1],
#  [8010186, 2],
#  [8012036, 0],
#  [8012036, 1],
#  [8012036, 2],
#  [8012037, 0],
#  [8012037, 1],
#  [8012037, 2],
#  [8012044, 0],
#  [8012044, 1],
#  [8012044, 2],
#  [8012045, 0],
#  [8012045, 1],
#  [8012045, 2],
#  [8012045, 3],
#  [8012046, 0],
#  [8012046, 1],
#  [8012046, 2],
#  [8012046, 3],
#  [8012047, 0],
#  [8012047, 1],
#  [8012047, 2],
#  [8012047, 3],
#  [8012053, 0],
#  [8012053, 1],
#  [8012053, 2],
#  [8012053, 3],
#  [8012059, 0],
#  [8012059, 1],
#  [8012059, 2],
#  [8012059, 3],
#  [8012059, 4],
#  [8012059, 5],
#  [8012059, 6],
#  [8012059, 7],
#  [8012059, 8],
#  [8012059, 9],
#  [8012059, 10],
#  [8012059, 11],
#  [8012059, 12],
#  [8012059, 13],
#  [8012059, 14],
#  [8012059, 15],
#  [8012059, 16],
#  [8012059, 17],
#  [8012059, 18],
#  [8012059, 19],
#  [8012059, 20],
#  [8012059, 21],
#  [8012059, 22],
#  [8012059, 23],
#  [8012061, 0],
#  [8012061, 1],
#  [8012061, 2],
#  [8012061, 3],
#  [8012067, 0],
#  [8012067, 1],
#  [8012067, 2],
#  [8012067, 3],
#  [8012072, 0],
#  [8012072, 1],
#  [8012072, 2],
#  [8012072, 3],
#  [8012079, 0],
#  [8012079, 1],
#  [8012079, 2],
#  [8012079, 3],
#  [8012097, 0],
#  [8012097, 1],
#  [8012097, 2],
#  [8012097, 3],
#  [8012105, 0],
#  [8012105, 1],
#  [8012105, 2],
#  [8012105, 3],
#  [8012113, 0],
#  [8012113, 1],
#  [8012113, 2],
#  [8012113, 3],
#  [8012115, 0],
#  [8012115, 1],
#  [8012115, 2],
#  [8012115, 3],
#  [8012117, 0],
#  [8012117, 1],
#  [8012117, 2],
#  [8012117, 3],
#  [8010040, 0],
#  [8010040, 1],
#  [8010040, 2],
#  [8010040, 3],
#  [8012138, 0],
#  [8012138, 1],
#  [8012138, 2],
#  [8012138, 3],
#  [8012141, 0],
#  [8012141, 1],
#  [8012141, 2],
#  [8012141, 3],
#  [8012145, 0],
#  [8012145, 1],
#  [8012145, 2],
#  [8012145, 3],
#  [8012150, 0],
#  [8012150, 1],
#  [8012150, 2],
#  [8012150, 3],
#  [8012163, 0],
#  [8012163, 1],
#  [8012163, 2],
#  [8012163, 3],
#  [8012164, 0],
#  [8012164, 1],
#  [8012164, 2],
#  [8012164, 3],
#  [8012170, 0],
#  [8012170, 1],
#  [8012170, 2],
#  [8012170, 3],
#  [8012174, 0],
#  [8012174, 1],
#  [8012174, 2],
#  [8012174, 3],
#  [8012175, 0],
#  [8012175, 1],
#  [8012175, 2],
#  [8012175, 3],
#  [8012178, 0],
#  [8012178, 1],
#  [8012178, 2],
#  [8012178, 3],
#  [8010205, 0],
#  [8010205, 1],
#  [8010205, 2],
#  [8010205, 3],
#  [8012343, 0],
#  [8012343, 1],
#  [8012343, 2],
#  [8012343, 3],
#  [8010206, 0],
#  [8010206, 1],
#  [8010206, 2],
#  [8010206, 3],
#  [8012188, 0],
#  [8012188, 1],
#  [8012188, 2],
#  [8012188, 3],
#  [8012190, 0],
#  [8012190, 1],
#  [8012190, 2],
#  [8012190, 3],
#  [8012192, 0],
#  [8012192, 1],
#  [8012192, 2],
#  [8012192, 3],
#  [8010207, 0],
#  [8010207, 1],
#  [8010207, 2],
#  [8010207, 3],
#  [8012193, 0],
#  [8012193, 1],
#  [8012193, 2],
#  [8012193, 3],
#  [8010208, 0],
#  [8010208, 1],
#  [8010208, 2],
#  [8010208, 3],
#  [8010209, 0],
#  [8010209, 1],
#  [8010209, 2],
#  [8010209, 3],
#  [8012194, 0],
#  [8012194, 1],
#  [8012194, 2],
#  [8012194, 3],
#  [8012195, 0],
#  [8012195, 1],
#  [8012195, 2],
#  [8012195, 3],
#  [8012197, 0],
#  [8012197, 1],
#  [8012197, 2],
#  [8012197, 3],
#  [8012198, 0],
#  [8012198, 1],
#  [8012198, 2],
#  [8012198, 3],
#  [8012203, 0],
#  [8012203, 1],
#  [8012203, 2],
#  [8012203, 3],
#  [8012220, 0],
#  [8012220, 1],
#  [8012220, 2],
#  [8012220, 3],
#  [8012223, 0],
#  [8012223, 1],
#  [8012223, 2],
#  [8012223, 3],
#  [8012224, 0],
#  [8012224, 1],
#  [8012224, 2],
#  [8012224, 3],
#  [8012228, 0],
#  [8012228, 1],
#  [8012228, 2],
#  [8012228, 3],
#  [8012231, 0],
#  [8012231, 1],
#  [8012231, 2],
#  [8012231, 3],
#  [8012232, 0],
#  [8012232, 1],
#  [8012232, 2],
#  [8012232, 3],
#  [8012236, 0],
#  [8012236, 1],
#  [8012236, 2],
#  [8012236, 3],
#  [8012236, 4],
#  [8010212, 0],
#  [8010212, 1],
#  [8010212, 2],
#  [8010212, 3],
#  [8010212, 4],
#  [8012241, 0],
#  [8012241, 1],
#  [8012241, 2],
#  [8012241, 3],
#  [8012241, 4],
#  [8012249, 0],
#  [8012249, 1],
#  [8012249, 2],
#  [8012249, 3],
#  [8012249, 4],
#  [8012250, 0],
#  [8012250, 1],
#  [8012250, 2],
#  [8012250, 3],
#  [8012250, 4],
#  [8012285, 0],
#  [8012285, 1],
#  [8012285, 2],
#  [8012285, 3],
#  [8012285, 4],
#  [8012284, 0],
#  [8012284, 1],
#  [8012284, 2],
#  [8012284, 3],
#  [8012284, 4],
#  [8012308, 0],
#  [8012308, 1],
#  [8012308, 2],
#  [8012308, 3],
#  [8012308, 4],
#  [8012309, 0],
#  [8012309, 1],
#  [8012309, 2],
#  [8012309, 3],
#  [8012309, 4],
#  [8010228, 0],
#  [8010228, 1],
#  [8010228, 2],
#  [8010228, 3],
#  [8010228, 4],
#  [8012311, 0],
#  [8012311, 1],
#  [8012311, 2],
#  [8012311, 3],
#  [8012311, 4],
#  [8012323, 0],
#  [8012323, 1],
#  [8012323, 2],
#  [8012323, 3],
#  [8012323, 4],
#  [8010229, 0],
#  [8010229, 1],
#  [8010229, 2],
#  [8010229, 3],
#  [8010229, 4],
#  [8012326, 0],
#  [8012326, 1],
#  [8012326, 2],
#  [8012326, 3],
#  [8012326, 4],
#  [8012327, 0],
#  [8012327, 1],
#  [8012327, 2],
#  [8012327, 3],
#  [8012327, 4],
#  [8012355, 0],
#  [8012355, 1],
#  [8012355, 2],
#  [8012355, 3],
#  [8012355, 4],
#  [8012344, 0],
#  [8012344, 1],
#  [8012344, 2],
#  [8012344, 3],
#  [8012344, 4],
#  [8010234, 0],
#  [8010234, 1],
#  [8010234, 2],
#  [8010234, 3],
#  [8010234, 4],
#  [8012369, 0],
#  [8012369, 1],
#  [8012369, 2],
#  [8012369, 3],
#  [8012369, 4],
#  [8012371, 0],
#  [8012371, 1],
#  [8012371, 2],
#  [8012371, 3],
#  [8012371, 4],
#  [8012375, 0],
#  [8012375, 1],
#  [8012375, 2],
#  [8012375, 3],
#  [8012375, 4],
#  [8012388, 0],
#  [8012388, 1],
#  [8012388, 2],
#  [8012388, 3],
#  [8012388, 4],
#  [8012391, 0],
#  [8012391, 1],
#  [8012391, 2],
#  [8012391, 3],
#  [8012391, 4],
#  [8012394, 0],
#  [8012394, 1],
#  [8012394, 2],
#  [8012394, 3],
#  [8012394, 4],
#  [8012407, 0],
#  [8012407, 1],
#  [8012407, 2],
#  [8012407, 3],
#  [8012407, 4],
#  [8012408, 0],
#  [8012408, 1],
#  [8012408, 2],
#  [8012408, 3],
#  [8012408, 4],
#  [8010238, 0],
#  [8010238, 1],
#  [8010238, 2],
#  [8010238, 3],
#  [8010238, 4],
#  [8012412, 0],
#  [8012412, 1],
#  [8012412, 2],
#  [8012412, 3],
#  [8012412, 4],
#  [8012416, 0],
#  [8012416, 1],
#  [8012416, 2],
#  [8012416, 3],
#  [8012416, 4],
#  [8012430, 0],
#  [8012430, 1],
#  [8012430, 2],
#  [8012430, 3],
#  [8012430, 4],
#  [8012454, 0],
#  [8012454, 1],
#  [8012454, 2],
#  [8012454, 3],
#  [8012454, 4],
#  [8010243, 0],
#  [8010243, 1],
#  [8010243, 2],
#  [8010243, 3],
#  [8010243, 4],
#  [8010243, 12],
#  [8010243, 13],
#  [8010243, 14],
#  [8010243, 15],
#  [8010243, 16],
#  [8010243, 17],
#  [8010243, 18],
#  [8010243, 19],
#  [8010243, 20],
#  [8010243, 21],
#  [8010243, 22],
#  [8010243, 23],
#  [8012460, 0],
#  [8012460, 1],
#  [8012460, 2],
#  [8012460, 3],
#  [8012460, 4],
#  [8012460, 5],
#  [8012460, 6],
#  [8012460, 7],
#  [8012460, 8],
#  [8012460, 9],
#  [8012460, 10],
#  [8012460, 11],
#  [8012460, 12],
#  [8012460, 13],
#  [8012460, 14],
#  [8012460, 15],
#  [8012460, 16],
#  [8012460, 17],
#  [8012460, 18],
#  [8012460, 19],
#  [8012460, 20],
#  [8012460, 21],
#  [8012460, 22],
#  [8012460, 23],
#  [8010400, 0],
#  [8010400, 1],
#  [8010400, 2],
#  [8010400, 3],
#  [8010400, 4],
#  [8010400, 5],
#  [8010400, 6],
#  [8010400, 7],
#  [8010400, 8],
#  [8010400, 9],
#  [8010400, 10],
#  [8010400, 11],
#  [8010400, 12],
#  [8010400, 13],
#  [8010400, 14],
#  [8010400, 15],
#  [8010400, 16],
#  [8010400, 17],
#  [8010400, 18],
#  [8010400, 19],
#  [8010400, 20],
#  [8010400, 21],
#  [8010400, 22],
#  [8010400, 23],
#  [8012463, 0],
#  [8012463, 1],
#  [8012463, 2],
#  [8012463, 3],
#  [8012463, 4],
#  [8010244, 0],
#  [8010244, 1],
#  [8010244, 2],
#  [8010244, 3],
#  [8010244, 4],
#  [8012470, 0],
#  [8012470, 1],
#  [8012470, 2],
#  [8012470, 3],
#  [8012470, 4],
#  [8012471, 0],
#  [8012471, 1],
#  [8012471, 2],
#  [8012471, 3],
#  [8012471, 4],
#  [8010249, 0],
#  [8010249, 1],
#  [8010249, 2],
#  [8010249, 3],
#  [8010249, 4],
#  [8012482, 0],
#  [8012482, 1],
#  [8012482, 2],
#  [8012482, 3],
#  [8012482, 4],
#  [8012483, 0],
#  [8012483, 1],
#  [8012483, 2],
#  [8012483, 3],
#  [8012483, 4],
#  [8012491, 0],
#  [8012491, 1],
#  [8012491, 2],
#  [8012491, 3],
#  [8012491, 4],
#  [8012497, 0],
#  [8012497, 1],
#  [8012497, 2],
#  [8012497, 3],
#  [8012497, 4],
#  [8000273, 0],
#  [8000273, 1],
#  [8000273, 2],
#  [8000273, 3],
#  [8000273, 4],
#  [8012503, 0],
#  [8012503, 1],
#  [8012503, 2],
#  [8012503, 3],
#  [8012503, 4],
#  [8010253, 0],
#  [8010253, 1],
#  [8010253, 2],
#  [8010253, 3],
#  [8010253, 4],
#  [8012505, 0],
#  [8012505, 1],
#  [8012505, 2],
#  [8012505, 3],
#  [8012505, 4],
#  [8013493, 0],
#  [8013493, 1],
#  [8013493, 2],
#  [8013493, 3],
#  [8013493, 4],
#  [8013493, 5],
#  [8012526, 0],
#  [8012526, 1],
#  [8012526, 2],
#  [8012526, 3],
#  [8012526, 4],
#  [8012526, 5],
#  [8012528, 0],
#  [8012528, 1],
#  [8012528, 2],
#  [8012528, 3],
#  [8012528, 4],
#  [8012528, 5],
#  [8010259, 0],
#  [8010259, 1],
#  [8010259, 2],
#  [8010259, 3],
#  [8010259, 4],
#  [8010259, 5],
#  [8012530, 0],
#  [8012530, 1],
#  [8012530, 2],
#  [8012530, 3],
#  [8012530, 4],
#  [8012530, 5],
#  [8012534, 0],
#  [8012534, 1],
#  [8012534, 2],
#  [8012534, 3],
#  [8012534, 4],
#  [8012534, 5],
#  [8012535, 0],
#  [8012535, 1],
#  [8012535, 2],
#  [8012535, 3],
#  [8012535, 4],
#  [8012535, 5],
#  [8012540, 0],
#  [8012540, 1],
#  [8012540, 2],
#  [8012540, 3],
#  [8012540, 4],
#  [8012540, 5],
#  [8012550, 0],
#  [8012550, 1],
#  [8012550, 2],
#  [8012550, 3],
#  [8012550, 4],
#  [8012550, 5],
#  [8012553, 0],
#  [8012553, 1],
#  [8012553, 2],
#  [8012553, 3],
#  [8012553, 4],
#  [8012553, 5],
#  [8012554, 0],
#  [8012554, 1],
#  [8012554, 2],
#  [8012554, 3],
#  [8012554, 4],
#  [8012554, 5],
#  [8013461, 0],
#  [8013461, 1],
#  [8013461, 2],
#  [8013461, 3],
#  [8013461, 4],
#  [8013461, 5],
#  [8012576, 0],
#  [8012576, 1],
#  [8012576, 2],
#  [8012576, 3],
#  [8012576, 4],
#  [8012576, 5],
#  [8012593, 0],
#  [8012593, 1],
#  [8012593, 2],
#  [8012593, 3],
#  [8012593, 4],
#  [8012593, 5],
#  [8012594, 0],
#  [8012594, 1],
#  [8012594, 2],
#  [8012594, 3],
#  [8012594, 4],
#  [8012594, 5],
#  [8012595, 0],
#  [8012595, 1],
#  [8012595, 2],
#  [8012595, 3],
#  [8012595, 4],
#  [8012595, 5],
#  [8012596, 0],
#  [8012596, 1],
#  [8012596, 2],
#  [8012596, 3],
#  [8012596, 4],
#  [8012596, 5],
#  [8012597, 0],
#  [8012597, 1],
#  [8012597, 2],
#  [8012597, 3],
#  [8012597, 4],
#  [8012597, 5],
#  [8010269, 0],
#  [8010269, 1],
#  [8010269, 2],
#  [8010269, 3],
#  [8010269, 4],
#  [8010269, 5],
#  [8012623, 0],
#  [8012623, 1],
#  [8012623, 2],
#  [8012623, 3],
#  [8012623, 4],
#  [8012623, 5],
#  [8012628, 0],
#  [8012628, 1],
#  [8012628, 2],
#  [8012628, 3],
#  [8012628, 4],
#  [8012628, 5],
#  [8012639, 0],
#  [8012639, 1],
#  [8012639, 2],
#  [8012639, 3],
#  [8012639, 4],
#  [8012639, 5],
#  [8010272, 0],
#  [8010272, 1],
#  [8010272, 2],
#  [8010272, 3],
#  [8010272, 4],
#  [8010272, 5],
#  [8012640, 0],
#  [8012640, 1],
#  [8012640, 2],
#  [8012640, 3],
#  [8012640, 4],
#  [8012640, 5],
#  [8010275, 0],
#  [8010275, 1],
#  [8010275, 2],
#  [8010275, 3],
#  [8010275, 4],
#  [8010275, 5],
#  [8012646, 0],
#  [8012646, 1],
#  [8012646, 2],
#  [8012646, 3],
#  [8012646, 4],
#  [8012646, 5],
#  [8012660, 0],
#  [8012660, 1],
#  [8012660, 2],
#  [8012660, 3],
#  [8012660, 4],
#  [8012660, 5],
#  [8012656, 0],
#  [8012656, 1],
#  [8012656, 2],
#  [8012656, 3],
#  [8012656, 4],
#  [8012656, 5],
#  [8012662, 0],
#  [8012662, 1],
#  [8012662, 2],
#  [8012662, 3],
#  [8012662, 4],
#  [8012662, 5],
#  [8010285, 0],
#  [8010285, 1],
#  [8010285, 2],
#  [8010285, 3],
#  [8010285, 4],
#  [8010285, 5],
#  [8012685, 0],
#  [8012685, 1],
#  [8012685, 2],
#  [8012685, 3],
#  [8012685, 4],
#  [8012685, 5],
#  [8012688, 0],
#  [8012688, 1],
#  [8012688, 2],
#  [8012688, 3],
#  [8012688, 4],
#  [8012688, 5],
#  [8012697, 0],
#  [8012697, 1],
#  [8012697, 2],
#  [8012697, 3],
#  [8012697, 4],
#  [8012697, 5],
#  [8012699, 0],
#  [8012699, 1],
#  [8012699, 2],
#  [8012699, 3],
#  [8012699, 4],
#  [8012699, 5],
#  [8010292, 0],
#  [8010292, 1],
#  [8010292, 2],
#  ...]

# %%
err1_stat, err1_hour = errors[0]
err1_stat, err1_hour
# Out:
# (8011132, 0)

# %%
req_url = timetable_url_pattern.format(base=timetable_base_url, station=err1_stat, date=today_short, hour=err1_hour)
req_url
# Out:
# 'https://api.deutschebahn.com/timetables/v1/plan/8011132/211028/00'

# %%
r = requests.get(req_url, headers=xml_headers)
r
# Out:
# <Response [200]>

# %%
r.text
# Out:
# '<?xml version=\'1.0\' encoding=\'UTF-8\'?><timetable station=\'Belgershain\'><s id="8575858415775127007-2110280010-9"><tl f="N" t="p" o="800413" c="RB" n="16661"/><ar pt="2110280034" pp="2" l="113" ppth="Leipzig Hbf|Leipzig-Paunsdorf|Leipzig Werkst&#228;ttenstra&#223;e|Leipzig-M&#246;lkau|Leipzig-Holzhausen|Leipzig-Liebertwolkwitz|Gro&#223;p&#246;sna|Oberholz"/><dp pt="2110280035" pp="2" l="113" ppth="Otterwisch|Lauterbach-Steinbach|Bad Lausick|Hopfgarten(Sachs)|Tautenhain|Geithain"/></s></timetable>'

# %%
timetable_idx = 0
n_timetable_combinations = len(errors)
error_combinations = []
for timetable in errors:
    stat, hour = timetable
    timetable_idx += 1
    
    req_url = timetable_url_pattern.format(base=timetable_base_url, station=stat, date=today_short, hour=hour)
    r = requests.get(req_url, headers=xml_headers)
    
    if r.status_code != 200:
        print("Error on request", timetable_idx, "(station={}, hour={})".format(stat, hour), " code =", r.status_code)
        error_combinations.append({"station": stat, "hour": hour, "status": r.status_code})
    
    outfile_name = base_dir + "/" + outfile_format.format(station=stat, hour=hour)
    with open(outfile_name, "w") as outfile:
        outfile.write(r.text)
    
    if timetable_idx % rate_limit == 0:
        print(timetable_idx, "timetables (of", n_timetable_combinations, ") so far. Taking a break.")
        time.sleep(60)
# Out:
# Error on request 2 (station=8011407, hour=0)  code = 400
# Error on request 3 (station=8011407, hour=1)  code = 400
# Error on request 4 (station=8011407, hour=2)  code = 400
# Error on request 5 (station=8011407, hour=3)  code = 400
# Error on request 6 (station=8011407, hour=4)  code = 400
# Error on request 7 (station=8011407, hour=5)  code = 400
# Error on request 8 (station=8011407, hour=6)  code = 400
# Error on request 9 (station=8011407, hour=7)  code = 400
# Error on request 10 (station=8011407, hour=8)  code = 400
# Error on request 11 (station=8011407, hour=9)  code = 400
# Error on request 12 (station=8011407, hour=10)  code = 400
# Error on request 13 (station=8011407, hour=11)  code = 400
# Error on request 14 (station=8011407, hour=12)  code = 400
# Error on request 15 (station=8011407, hour=13)  code = 400
# Error on request 16 (station=8011407, hour=14)  code = 400
# Error on request 17 (station=8011407, hour=15)  code = 400
# Error on request 18 (station=8011407, hour=16)  code = 400
# Error on request 19 (station=8011407, hour=17)  code = 400
# Error on request 20 (station=8011407, hour=18)  code = 400
# 20 timetables (of 69 ) so far. Taking a break.
# Error on request 21 (station=8011407, hour=19)  code = 400
# Error on request 22 (station=8011407, hour=20)  code = 400
# Error on request 23 (station=8011407, hour=21)  code = 400
# Error on request 24 (station=8011407, hour=22)  code = 400
# Error on request 25 (station=8011407, hour=23)  code = 400
# 40 timetables (of 69 ) so far. Taking a break.
# Error on request 46 (station=8012059, hour=0)  code = 400
# Error on request 47 (station=8012059, hour=1)  code = 400
# Error on request 48 (station=8012059, hour=2)  code = 400
# Error on request 49 (station=8012059, hour=3)  code = 400
# Error on request 50 (station=8012059, hour=4)  code = 400
# Error on request 51 (station=8012059, hour=5)  code = 400
# Error on request 52 (station=8012059, hour=6)  code = 400
# Error on request 53 (station=8012059, hour=7)  code = 400
# Error on request 54 (station=8012059, hour=8)  code = 400
# Error on request 55 (station=8012059, hour=9)  code = 400
# Error on request 56 (station=8012059, hour=10)  code = 400
# Error on request 57 (station=8012059, hour=11)  code = 400
# Error on request 58 (station=8012059, hour=12)  code = 400
# Error on request 59 (station=8012059, hour=13)  code = 400
# Error on request 60 (station=8012059, hour=14)  code = 400
# 60 timetables (of 69 ) so far. Taking a break.
# Error on request 61 (station=8012059, hour=15)  code = 400
# Error on request 62 (station=8012059, hour=16)  code = 400
# Error on request 63 (station=8012059, hour=17)  code = 400
# Error on request 64 (station=8012059, hour=18)  code = 400
# Error on request 65 (station=8012059, hour=19)  code = 400
# Error on request 66 (station=8012059, hour=20)  code = 400
# Error on request 67 (station=8012059, hour=21)  code = 400
# Error on request 68 (station=8012059, hour=22)  code = 400
# Error on request 69 (station=8012059, hour=23)  code = 400

# %%
with open("timetables/errors_rerun2.json", "w") as error_file:
    json.dump(error_combinations, error_file)

# %% [markdown]
# ## Merge and convert all timetables into a more usefull data structure

# %%
import lxml
import lxml.etree
import lxml.objectify

# %%
def getchildtags(node):
    return [c.tag for c in node.getchildren()]

# %%
def joinDropNone(iterable, delim):
    return delim.join([x for x in iterable if x is not None])

# %%
test_file = open("timetables/timetable_8000273_05.xml", "r")
parsed = lxml.objectify.parse(test_file)
parsed

# %%
lxml.objectify.dump(parsed.getroot())
# Out:
# "timetable = None [ObjectifiedElement]\n  * station = 'Muldenberg Floßplatz'\n    s = None [ObjectifiedElement]\n      * id = '3991938303171863868-2110270532-4'\n        tl = '' [StringElement]\n          * c = 'VBG'\n          * f = 'D'\n          * n = '20802'\n          * o = 'RD'\n          * t = 'p'\n        ar = '' [StringElement]\n          * l = 'RB1'\n          * pp = '1'\n          * ppth = 'Zwotental|Schöneck(Vogtl) Ferienpark|Schöneck(Vogtl)'\n          * pt = '2110270544'\n        dp = '' [StringElement]\n          * l = 'RB1'\n          * pp = '1'\n          * ppth = 'Grünbach(Vogtl)|Falkenstein(Vogtl)|Ellefeld|Auerbach(V) unt Bf|Rodewisch|Lengenfeld(Vogtl)|Irfersgrün|Voigtsgrün|Ebersbrunn|Stenn|Zwickau(Sachs)Hbf|Zwickau Stadthalle|Zwickau Zentrum'\n          * pt = '2110270544'\n    s = None [ObjectifiedElement]\n      * id = '4048785167705909746-2110270503-3'\n        tl = '' [StringElement]\n          * c = 'VBG'\n          * f = 'D'\n          * n = '20801'\n          * o = 'RD'\n          * t = 'p'\n        ar = '' [StringElement]\n          * l = 'RB1'\n          * pp = '1'\n          * ppth = 'Falkenstein(Vogtl)|Grünbach(Vogtl)'\n          * pt = '2110270515'\n        dp = '' [StringElement]\n          * l = 'RB1'\n          * pp = '1'\n          * ppth = 'Schöneck(Vogtl)|Schöneck(Vogtl) Ferienpark|Zwotental'\n          * pt = '2110270515'"

# %%
timetable_node = parsed.getroot()

# %%
timetable_node.s.get("id")
# Out:
# '3991938303171863868-2110270532-4'

# %%
station = timetable_node.get("station"), timetable_node.get("eva")
station
# Out:
# ('Muldenberg Floßplatz', None)

# %%
connection_nodes = timetable_node.getchildren()

# %%
connections = []
for cn in connection_nodes:
    line = {"train_type": cn.tl.get("c")}
    route_before = None
    route_after = None
    if "ar" in getchildtags(cn):
        line["line"] = cn.ar.get("l")
    elif "dp" in getchildtags(cn):
        line["line"] = cn.dp.get("l")
    else:
        line["line"] = ""
        
    if "ar" in getchildtags(cn):
        route_before = cn.ar.get("ppth")
    if "dp" in getchildtags(cn):
        route_after = cn.dp.get("ppth")
    complete_route = joinDropNone([route_before, station[0], route_after], "|")
    line["route"] = complete_route
    
    connections.append(line)

connections
# Out:
# [{'train_type': 'VBG',
#   'line': 'RB1',
#   'route': 'Zwotental|Schöneck(Vogtl) Ferienpark|Schöneck(Vogtl)|Muldenberg Floßplatz|Grünbach(Vogtl)|Falkenstein(Vogtl)|Ellefeld|Auerbach(V) unt Bf|Rodewisch|Lengenfeld(Vogtl)|Irfersgrün|Voigtsgrün|Ebersbrunn|Stenn|Zwickau(Sachs)Hbf|Zwickau Stadthalle|Zwickau Zentrum'},
#  {'train_type': 'VBG',
#   'line': 'RB1',
#   'route': 'Falkenstein(Vogtl)|Grünbach(Vogtl)|Muldenberg Floßplatz|Schöneck(Vogtl)|Schöneck(Vogtl) Ferienpark|Zwotental'}]

# %%
def extract_connection_data(timetable):
    timetable_node = parsed.getroot()
    station = timetable_node.get("station"), timetable_node.get("eva")
    
    connection_nodes = timetable_node.getchildren()
    connections = []
    
    for cn in connection_nodes:
        line = {"train_type": cn.tl.get("c"), "extracted_from": station[0]}
        route_before = None
        route_after = None
        if "ar" in getchildtags(cn):
            line["line"] = cn.ar.get("l")
        elif "dp" in getchildtags(cn):
            line["line"] = cn.dp.get("l")
        else:
            line["line"] = ""

        if "ar" in getchildtags(cn):
            route_before = cn.ar.get("ppth")
        if "dp" in getchildtags(cn):
            route_after = cn.dp.get("ppth")
        complete_route = joinDropNone([route_before, station[0], route_after], "|")
        line["route"] = complete_route

        connections.append(line)
    
    return connections

# %%
extract_connection_data(parsed)
# Out:
# [{'train_type': 'VBG',
#   'extracted_from': 'Muldenberg Floßplatz',
#   'line': 'RB1',
#   'route': 'Zwotental|Schöneck(Vogtl) Ferienpark|Schöneck(Vogtl)|Muldenberg Floßplatz|Grünbach(Vogtl)|Falkenstein(Vogtl)|Ellefeld|Auerbach(V) unt Bf|Rodewisch|Lengenfeld(Vogtl)|Irfersgrün|Voigtsgrün|Ebersbrunn|Stenn|Zwickau(Sachs)Hbf|Zwickau Stadthalle|Zwickau Zentrum'},
#  {'train_type': 'VBG',
#   'extracted_from': 'Muldenberg Floßplatz',
#   'line': 'RB1',
#   'route': 'Falkenstein(Vogtl)|Grünbach(Vogtl)|Muldenberg Floßplatz|Schöneck(Vogtl)|Schöneck(Vogtl) Ferienpark|Zwotental'}]

# %%
import pathlib

# %%
all_connections = []
for timetable_xml in pathlib.Path("timetables").glob("*.xml"):
    with open(timetable_xml, "r") as timetable_file:
        try:
            parsed = lxml.objectify.parse(timetable_file)
            all_connections += extract_connection_data(parsed)
        except lxml.etree.XMLSyntaxError:
            print("Could not parse", timetable_xml)
len(all_connections)
# Out:
# Could not parse timetables\timetable_8011407_00.xml
# Could not parse timetables\timetable_8011407_01.xml
# Could not parse timetables\timetable_8011407_02.xml
# Could not parse timetables\timetable_8011407_03.xml
# Could not parse timetables\timetable_8011407_04.xml
# Could not parse timetables\timetable_8011407_05.xml
# Could not parse timetables\timetable_8011407_06.xml
# Could not parse timetables\timetable_8011407_07.xml
# Could not parse timetables\timetable_8011407_08.xml
# Could not parse timetables\timetable_8011407_09.xml
# Could not parse timetables\timetable_8011407_10.xml
# Could not parse timetables\timetable_8011407_11.xml
# Could not parse timetables\timetable_8011407_12.xml
# Could not parse timetables\timetable_8011407_13.xml
# Could not parse timetables\timetable_8011407_14.xml
# Could not parse timetables\timetable_8011407_15.xml
# Could not parse timetables\timetable_8011407_16.xml
# Could not parse timetables\timetable_8011407_17.xml
# Could not parse timetables\timetable_8011407_18.xml
# Could not parse timetables\timetable_8011407_19.xml
# Could not parse timetables\timetable_8011407_20.xml
# Could not parse timetables\timetable_8011407_21.xml
# Could not parse timetables\timetable_8011407_22.xml
# Could not parse timetables\timetable_8011407_23.xml
# Could not parse timetables\timetable_8012059_00.xml
# Could not parse timetables\timetable_8012059_01.xml
# Could not parse timetables\timetable_8012059_02.xml
# Could not parse timetables\timetable_8012059_03.xml
# Could not parse timetables\timetable_8012059_04.xml
# Could not parse timetables\timetable_8012059_05.xml
# Could not parse timetables\timetable_8012059_06.xml
# Could not parse timetables\timetable_8012059_07.xml
# Could not parse timetables\timetable_8012059_08.xml
# Could not parse timetables\timetable_8012059_09.xml
# Could not parse timetables\timetable_8012059_10.xml
# Could not parse timetables\timetable_8012059_11.xml
# Could not parse timetables\timetable_8012059_12.xml
# Could not parse timetables\timetable_8012059_13.xml
# Could not parse timetables\timetable_8012059_14.xml
# Could not parse timetables\timetable_8012059_15.xml
# Could not parse timetables\timetable_8012059_16.xml
# Could not parse timetables\timetable_8012059_17.xml
# Could not parse timetables\timetable_8012059_18.xml
# Could not parse timetables\timetable_8012059_19.xml
# Could not parse timetables\timetable_8012059_20.xml
# Could not parse timetables\timetable_8012059_21.xml
# Could not parse timetables\timetable_8012059_22.xml
# Could not parse timetables\timetable_8012059_23.xml
# 28890

# %%
all_connections[-4:]
# Out:
# [{'train_type': 'RB',
#   'extracted_from': 'Leipzig-Sellerhausen',
#   'line': '110',
#   'route': 'Leipzig Hbf|Leipzig-Sellerhausen|Leipzig-Paunsdorf|Leipzig-Engelsdorf|Borsdorf(Sachs)|Beucha|Naunhof|Großsteinberg|Grimma ob Bf|Großbothen|Tanndorf|Leisnig|Klosterbuch|Westewitz-Hochweitzschen|Döbeln Hbf'},
#  {'train_type': 'RB',
#   'extracted_from': 'Leipzig-Sellerhausen',
#   'line': '110',
#   'route': 'Grimma ob Bf|Großsteinberg|Naunhof|Beucha|Borsdorf(Sachs)|Leipzig-Engelsdorf|Leipzig-Paunsdorf|Leipzig-Sellerhausen|Leipzig Hbf'},
#  {'train_type': 'RB',
#   'extracted_from': 'Leipzig-Sellerhausen',
#   'line': '110',
#   'route': 'Leipzig Hbf|Leipzig-Sellerhausen|Leipzig-Paunsdorf|Leipzig-Engelsdorf|Borsdorf(Sachs)|Beucha|Naunhof|Großsteinberg|Grimma ob Bf'},
#  {'train_type': 'RB',
#   'extracted_from': 'Leipzig-Sellerhausen',
#   'line': '110',
#   'route': 'Grimma ob Bf|Großsteinberg|Naunhof|Beucha|Borsdorf(Sachs)|Leipzig-Engelsdorf|Leipzig-Paunsdorf|Leipzig-Sellerhausen|Leipzig Hbf'}]

# %%
with open("timetables/complete_timetables.json", "w") as timetables_output:
    json.dump(all_connections, timetables_output)

# %%
import pandas as pd

# %%
tt_df = pd.DataFrame(all_connections)
tt_df
# Out:
#       train_type        extracted_from line  \
# 0            VBG  Muldenberg Floßplatz  RB1
# 1            VBG  Muldenberg Floßplatz  RB1
# 2            VBG  Muldenberg Floßplatz  RB1
# 3            VBG  Muldenberg Floßplatz  RB5
# 4            VBG  Muldenberg Floßplatz  RB5
# ...          ...                   ...  ...
# 28885         RB  Leipzig-Sellerhausen  110
# 28886         RB  Leipzig-Sellerhausen  110
# 28887         RB  Leipzig-Sellerhausen  110
# 28888         RB  Leipzig-Sellerhausen  110
# 28889         RB  Leipzig-Sellerhausen  110
#
#                                                    route
# 0      Zwotental|Schöneck(Vogtl) Ferienpark|Schöneck(...
# 1      Falkenstein(Vogtl)|Grünbach(Vogtl)|Muldenberg ...
# 2      Zwotental|Schöneck(Vogtl) Ferienpark|Schöneck(...
# 3      Plauen(Vogtl) ob Bf|Jößnitz|Jocketa|Ruppertsgr...
# 4      Zwotental|Schöneck(Vogtl) Ferienpark|Schöneck(...
# ...                                                  ...
# 28885  Döbeln Hbf|Westewitz-Hochweitzschen|Klosterbuc...
# 28886  Leipzig Hbf|Leipzig-Sellerhausen|Leipzig-Pauns...
# 28887  Grimma ob Bf|Großsteinberg|Naunhof|Beucha|Bors...
# 28888  Leipzig Hbf|Leipzig-Sellerhausen|Leipzig-Pauns...
# 28889  Grimma ob Bf|Großsteinberg|Naunhof|Beucha|Bors...
#
# [28890 rows x 4 columns]

# %%
tt_df.sort_values(by=["line", "train_type"])
# Out:
#      train_type extracted_from  line  \
# 363           S   Bad Schandau     1
# 364           S   Bad Schandau     1
# 365           S   Bad Schandau     1
# 366           S   Bad Schandau     1
# 368           S   Bad Schandau     1
# ...         ...            ...   ...
# 8560        SOE         Zittau  None
# 8566        SOE         Zittau  None
# 8572        SOE         Zittau  None
# 8584        SOE         Zittau  None
# 8598        SOE         Zittau  None
#
#                                                   route
# 363   Bad Schandau|Königstein(Sächs Schw)|Kurort Rat...
# 364   Meißen Triebischtal|Meißen Altstadt|Meißen|Neu...
# 365   Schöna|Schmilka-Hirschmühle|Krippen|Bad Schand...
# 366   Dresden Hbf|Dresden-Strehlen|Dresden-Reick|Dre...
# 368   Schöna|Schmilka-Hirschmühle|Krippen|Bad Schand...
# ...                                                 ...
# 8560  Zittau|Zittau Hp|Zittau Süd|Zittau Vorstadt|Ol...
# 8566  Kurort Oybin|Teufelsmühle|Kurort Oybin-Niederd...
# 8572  Zittau|Zittau Hp|Zittau Süd|Zittau Vorstadt|Ol...
# 8584  Kurort Oybin|Teufelsmühle|Kurort Oybin-Niederd...
# 8598  Kurort Jonsdorf|Kurort Jonsdorf Hst|Bertsdorf|...
#
# [28890 rows x 4 columns]

# %%
def adjust_route_order(stops):
    if len(stops) < 2:
        return stops
    first_stop = stops[0]
    last_stop = stops[-1]
    if first_stop > last_stop:
        return list(reversed(stops))
    else:
        return stops

# %%
tt_df["route_normalized"] = tt_df.route.str.split("|").apply(adjust_route_order)
tt_df["route_normalized_str"] = tt_df.route_normalized.str.join("|")

# %%
tt_route_grp = tt_df.groupby("route_normalized_str")
len(tt_route_grp)
# Out:
# 328

# %%
tt_unique_route = tt_route_grp.first().reset_index()

# %%
tt_unique_route[tt_unique_route.line == "S5"]
# Out:
#                                   route_normalized_str train_type  \
# 4    Altenburg|Treben-Lehma|Regis-Breitingen|Deutze...        Bus
# 44   Böhlen(Leipzig)|Böhlen Werke|Neukieritzsch|Deu...        Bus
# 323  Werdau|Steinpleis|Lichtentanne(Sachs)|Zwickau(...        Bus
#
#     extracted_from line                                              route  \
# 4    Neukieritzsch   S5  Altenburg|Treben-Lehma|Regis-Breitingen|Deutze...
# 44   Neukieritzsch   S5  Gößnitz|Lehndorf(Altenburg)|Altenburg|Treben-L...
# 323     Steinpleis   S5  Werdau|Steinpleis|Lichtentanne(Sachs)|Zwickau(...
#
#                                       route_normalized
# 4    [Altenburg, Treben-Lehma, Regis-Breitingen, De...
# 44   [Böhlen(Leipzig), Böhlen Werke, Neukieritzsch,...
# 323  [Werdau, Steinpleis, Lichtentanne(Sachs), Zwic...

# %%
tt_unique_route[tt_unique_route.line == "S5"].route.values
# Out:
# array(['Altenburg|Treben-Lehma|Regis-Breitingen|Deutzen Markt|Neukieritzsch|Böhlen Werke|Böhlen(Leipzig)',
#        'Gößnitz|Lehndorf(Altenburg)|Altenburg|Treben-Lehma|Regis-Breitingen|Deutzen Markt|Neukieritzsch|Böhlen Werke|Böhlen(Leipzig)',
#        'Werdau|Steinpleis|Lichtentanne(Sachs)|Zwickau(Sachs)Hbf'],
#       dtype=object)

# %%
tt_projected = tt_unique_route[["train_type", "extracted_from", "line", "route_normalized"]]
tt_projected
# Out:
#     train_type        extracted_from line  \
# 0          VBG          Adorf(Vogtl)  RB4
# 1          VBG          Adorf(Vogtl)  RB2
# 2          VBG          Adorf(Vogtl)  RB2
# 3            S            Steinpleis    5
# 4          Bus         Neukieritzsch   S5
# ..         ...                   ...  ...
# 323        Bus            Steinpleis   S5
# 324        VBG  Muldenberg Floßplatz  RB1
# 325        VBG  Muldenberg Floßplatz  RB1
# 326        VBG  Muldenberg Floßplatz  RB1
# 327        Bus             Zwotental  SEV
#
#                                       route_normalized
# 0    [Adorf(Vogtl), Hundsgrün, Oelsnitz(Vogtl), Pir...
# 1    [Adorf(Vogtl), Hundsgrün, Oelsnitz(Vogtl), Pir...
# 2    [Adorf(Vogtl), Hundsgrün, Oelsnitz(Vogtl), Pir...
# 3    [Altenburg, Lehndorf(Altenburg), Gößnitz, Poni...
# 4    [Altenburg, Treben-Lehma, Regis-Breitingen, De...
# ..                                                 ...
# 323  [Werdau, Steinpleis, Lichtentanne(Sachs), Zwic...
# 324  [Zwickau Stadthalle, Zwickau(Sachs)Hbf, Stenn,...
# 325  [Zwickau Zentrum, Zwickau Stadthalle, Zwickau(...
# 326  [Zwickau Zentrum, Zwickau Stadthalle, Zwickau(...
# 327                      [Zwota-Zechenbach, Zwotental]
#
# [328 rows x 4 columns]

# %%
tt_projected.to_json("timetables/timetables.json", index=False, orient="table")
